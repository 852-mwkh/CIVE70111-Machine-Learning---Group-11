# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/0/06/Imperial_College_London_new_logo.png" alt="Imperial Logo" width="400">
#
# ### **Course:** CIVE70111 Machine Learning
# ### Task 6 PV Plant Modelling and Machine Learning Pipeline
#
# **Project:** Temporal Forecasting
#
# **Date:** 09/12/2025
#
# <p align="right">
# Created by: Michael Wong

# %% [markdown]
# # Table of Contents
#
# 1. Project Overview
# 2. Workflow Summary
# 3. Data Cleaning & Preprocessing
#    - Plant 1
#    - Plant 2
# 4. Feature Engineering
# 5. Task 4 – Linear SVC Classification Model
#    - Label construction
#    - Feature preparation
#    - Temporal splitting
#    - Model training
#    - Threshold optimisation
#    - Evaluation
# 6. Task 6 – LSTM Forecasting Model (PyTorch)
#    - Sequence construction
#    - Model architecture
#    - Training procedure
#    - Baseline models
#    - Evaluation
# 7. Results Summary
# 8. Discussion & Conclusions
# 9. Appendix – Full Python Code

# %% [markdown]
# # Project Overview
#
# This project analyses the operational condition and power performance of two solar photovoltaic plants.
# The objectives are:
#
# 1. **Classify operating conditions (Optimal vs Suboptimal)**
#    Using a **Linear SVC** model with engineered physical features (irradiation ratios, temperature deltas, time-of-day cyclic encoding).
#
# 2. **Forecast AC and DC power 1 hour ahead**
#    Using a **PyTorch LSTM regression model**, evaluated against persistence and moving-average baselines.
#
# The workflow includes extensive **data cleaning**, **sensor consistency checks**, **irradiance-based filtering**, **yield reconstruction**, and advanced modelling using both **scikit-learn** and **PyTorch**.
#
# Both plants are processed symmetrically to allow comparisons across inverters and locations.

# %% [markdown]
# # Workflow Summary
#
# ### Step 1 — Load and Clean Raw Data
# - Parse timestamps (including mixed formats in Plant 1).
# - Remove or correct invalid readings.
# - Clean irradiance using a day/night rule.
# - Clean AC/DC power based on irradiance availability.
# - Interpolate and enforce monotonicity in DAILY and TOTAL yields.
#
# ### Step 2 — Merge Generation Data with Weather Data
# - Create per-inverter datasets.
# - Join inverter and weather time series.
# - Produce cleaned dictionaries:
#   - `df_ps1` (Plant 1)
#   - `df_ps2` (Plant 2)
#
# ### Step 3 — Feature Engineering
# - Efficiency ratios (DC/IRRA, AC/IRRA)
# - Module temperature delta
# - Cyclic time-of-day encoding (cosine)
#
# ### Step 4 — Operating Condition Classification (Task 4)
# - Build labels: Optimal = 0, Suboptimal = 1
# - Scale numerical features using pipeline
# - Fit Linear SVC with balanced class weights
# - Optimise threshold using validation PR curve (maximising F1 for suboptimal)
# - Evaluate on temporal test segment
#
# ### Step 5 — LSTM Forecasting (Task 6)
# - Construct sequences (24h window → 1h horizon)
# - Normalise features with MinMaxScaler
# - Train PyTorch LSTM on each inverter
# - Early stopping using validation loss
# - Compare against:
#   - Persistence baseline
#   - Moving average baseline
#
# ### Step 6 — Summarise Performance
# - Per-inverter MAE & RMSE
# - Average errors across all inverters
# - Interpretation of classification and forecasting performance

# %% [markdown]
# ### Imports

# %%
import os
import math
import datetime as dt
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display

import pickle  # <-- ADD THIS LINE

from sklearn.metrics import (
    auc, precision_recall_curve, classification_report, confusion_matrix,
    f1_score, precision_score, recall_score, average_precision_score,
    mean_absolute_error, mean_squared_error
)

from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.utils.class_weight import compute_class_weight

from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.inspection import PartialDependenceDisplay, permutation_importance

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset

# %% [markdown]
# ### Data Paths

# %%
####################################################################################################################################################

# Change here

folder = r"C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\In"

####################################################################################################################################################
gen_path_1 = os.path.join(folder, "Plant_1_Generation_Data_updated.csv")
weather_path_1 = os.path.join(folder, "Plant_1_Weather_Sensor_Data.csv")
gen_path_2 = os.path.join(folder, "Plant_2_Generation_Data.csv")
weather_path_2 = os.path.join(folder, "Plant_2_Weather_Sensor_Data.csv")

# %% [markdown]
# # Data Cleaning & Preprocessing
#
# Both plants required substantial preprocessing due to:
# - Time format inconsistencies
# - Sensor noise and missing values
# - Physically inconsistent readings (e.g., power at night)
# - Non-monotonic yield curves
#
# ### Plant 1
# - Fixed DATE_TIME using dual-format parsing.
# - Removed rows missing the operating condition.
# - Aggregated per inverter with counts of Optimal and Suboptimal states.
# - Cleaned irradiance using a day/night rule and interpolation.
# - Enforced physically consistent AC/DC values based on irradiance.
# - Reconstructed DAILY and TOTAL yields with monotonic constraints.
# - Generated final cleaned dictionary `df_ps1`.
#
# ### Plant 2
# - Performed identical cleaning and reconstruction steps.
# - Generated dictionary `df_ps2`.
#
# Both cleaned plants include:
# - AC_CLEAN
# - DC_CLEAN
# - DAILY_YIELD_CLEAN
# - TOTAL_YIELD_CLEAN
# - AMBIENT_TEMPERATURE
# - MODULE_TEMPERATURE
# - IRRADIATION_CLEAN
# - OPERATING_CONDITION_CLEAN

# %% [markdown]
# ##### PLANT 1 CLEANING

# %%
### ============================================
### Plant 1: Clean and merge generation + weather
### ============================================

# Correct time issue for Plant 1 generation data
df = pd.read_csv(gen_path_1)
start = pd.Timestamp("2020-05-15")
end = pd.Timestamp("2020-06-18")

df["parsed"] = pd.to_datetime(df["DATE_TIME"], format="%Y-%m-%d %H:%M:%S", errors="coerce")
invalid = df["parsed"].isna() | (~df["parsed"].between(start, end))
df.loc[invalid, "parsed"] = pd.to_datetime(
    df.loc[invalid, "DATE_TIME"], format="%Y-%d-%m %H:%M:%S", errors="coerce"
)
df["DATE_TIME"] = df["parsed"]
dfc = df.drop(columns=["parsed"])

# Drop rows with missing operating condition
plant_1_c = dfc.dropna()
plant_1_c = plant_1_c.drop(columns=["PLANT_ID", "day"])
plant_1_c.set_index("DATE_TIME", inplace=True)

# Separate into inverter dataframes
source_key_1 = plant_1_c["SOURCE_KEY"].unique().tolist()
p1c_gp = plant_1_c.groupby("SOURCE_KEY")
inv_1 = {SOURCE_KEY: group for SOURCE_KEY, group in p1c_gp}

# Aggregate by time for each inverter
agg_inv_1 = {}
for sk, df_inv in inv_1.items():
    agg_df = df_inv.groupby("DATE_TIME").agg(
        SOURCE_KEY=("SOURCE_KEY", "first"),
        DC_POWER=("DC_POWER", "first"),
        AC_POWER=("AC_POWER", "first"),
        DAILY_YIELD=("DAILY_YIELD", "first"),
        TOTAL_YIELD=("TOTAL_YIELD", "first"),
        NUM_OPT=("Operating_Condition", lambda x: (x == "Optimal").sum()),
        NUM_SUBOPT=("Operating_Condition", lambda x: (x == "Suboptimal").sum()),
    ).reset_index()
    agg_inv_1[sk] = agg_df

# Load Plant 1 weather
df = pd.read_csv(weather_path_1)
df["DATE_TIME"] = pd.to_datetime(df["DATE_TIME"])

# Day/night rule
day_start = dt.time(6, 0)
day_end = dt.time(18, 30)
df["expected_day"] = df["DATE_TIME"].dt.time.between(day_start, day_end)

# Clean irradiation data
df["IRRADIATION_CLEAN"] = df["IRRADIATION"].copy()
df.loc[(~df["expected_day"]) & (df["IRRADIATION_CLEAN"] > 0), "IRRADIATION_CLEAN"] = 0
df.loc[(df["expected_day"]) & (df["IRRADIATION_CLEAN"] == 0), "IRRADIATION_CLEAN"] = float("nan")
df["IRRADIATION_CLEAN"] = df["IRRADIATION_CLEAN"].interpolate(method="linear")
df["IRRADIATION_CLEAN"] = df["IRRADIATION_CLEAN"].fillna(0)

s1_c = df.copy()
s1_c.set_index("DATE_TIME", inplace=True)
s1_c = s1_c.drop(columns=["SOURCE_KEY"])

# Join inverter data with weather
wea_inv_1 = {}
for sk, df_inv in agg_inv_1.items():
    df_inv = df_inv.set_index("DATE_TIME")
    join_df = df_inv.join(s1_c, how="inner")
    wea_inv_1[sk] = join_df

# Clean AC/DC and DAILY_YIELD for each inverter
df_step_1 = {}
for sk, df_inv in wea_inv_1.items():
    df_clean = df_inv.copy()
    df_clean["AC_CLEAN"] = df_clean["AC_POWER"].copy()
    df_clean["DC_CLEAN"] = df_clean["DC_POWER"].copy()

    night_mask = df_clean["IRRADIATION_CLEAN"] == 0
    df_clean.loc[night_mask & (df_clean["AC_CLEAN"] > 0), "AC_CLEAN"] = 0
    df_clean.loc[night_mask & (df_clean["DC_CLEAN"] > 0), "DC_CLEAN"] = 0

    day_mask = df_clean["IRRADIATION_CLEAN"] > 0
    df_clean.loc[day_mask & (df_clean["AC_CLEAN"] == 0), "AC_CLEAN"] = float("nan")
    df_clean.loc[day_mask & (df_clean["DC_CLEAN"] == 0), "DC_CLEAN"] = float("nan")

    df_clean["AC_CLEAN"] = df_clean["AC_CLEAN"].interpolate(method="linear")
    df_clean["DC_CLEAN"] = df_clean["DC_CLEAN"].interpolate(method="linear")
    df_clean["AC_CLEAN"] = df_clean["AC_CLEAN"].fillna(0)
    df_clean["DC_CLEAN"] = df_clean["DC_CLEAN"].fillna(0)

    df_step_1[sk] = df_clean

# DAILY_YIELD_CLEAN reconstruction
df_step_2 = {}
for sk, df_inv in df_step_1.items():
    df_clean = df_inv.copy()
    df_clean.index = pd.to_datetime(df_clean.index)
    df_clean["DAILY_YIELD_CLEAN"] = df_clean["DAILY_YIELD"].copy()

    dates = np.unique(df_clean.index.date)
    for d in dates:
        day_mask_full = df_clean.index.date == d
        df_day = df_clean.loc[day_mask_full]
        irr_pos = df_day["IRRADIATION_CLEAN"] > 0

        if not irr_pos.any():
            df_clean.loc[day_mask_full, "DAILY_YIELD_CLEAN"] = 0.0
            continue

        day_start_idx = df_day[irr_pos].index[0]
        day_end_idx = df_day[irr_pos].index[-1]

        night_mask = day_mask_full & (df_clean.index < day_start_idx)
        day_mask = day_mask_full & (df_clean.index >= day_start_idx) & (df_clean.index <= day_end_idx)
        evening_mask = day_mask_full & (df_clean.index > day_end_idx)

        df_clean.loc[night_mask, "DAILY_YIELD_CLEAN"] = 0.0
        val_end = df_clean.at[day_end_idx, "DAILY_YIELD"]
        df_clean.loc[evening_mask, "DAILY_YIELD_CLEAN"] = val_end

        day_idx = df_clean.loc[day_mask].index
        if len(day_idx) == 0:
            continue

        raw_vals = df_clean.loc[day_idx, "DAILY_YIELD_CLEAN"].values.astype(float)
        invalid = np.zeros(len(raw_vals), dtype=bool)
        invalid |= raw_vals <= 0

        if len(raw_vals) > 1:
            drops = np.diff(raw_vals) < 0
            invalid[1:][drops] = True

        df_clean.loc[day_idx[invalid], "DAILY_YIELD_CLEAN"] = np.nan
        df_clean.loc[day_idx, "DAILY_YIELD_CLEAN"] = (
            df_clean.loc[day_idx, "DAILY_YIELD_CLEAN"]
            .interpolate(method="linear", limit_direction="both")
        )

        prev_val = df_clean.at[day_idx[0], "DAILY_YIELD_CLEAN"]
        for t in day_idx[1:]:
            cur = df_clean.at[t, "DAILY_YIELD_CLEAN"]
            if pd.isna(cur) or cur < prev_val:
                df_clean.at[t, "DAILY_YIELD_CLEAN"] = prev_val
            else:
                prev_val = cur

        df_clean.loc[night_mask, "DAILY_YIELD_CLEAN"] = 0.0
        df_clean.loc[evening_mask, "DAILY_YIELD_CLEAN"] = val_end

    df_step_2[sk] = df_clean

# TOTAL_YIELD_CLEAN reconstruction
df_ps1 = {}
for sk, df_inv in df_step_2.items():
    df_clean = df_inv.copy()
    df_clean["TOTAL_YIELD_CLEAN"] = df_clean["TOTAL_YIELD"].copy()
    timestamps = df_clean.index

    for i in range(1, len(timestamps)):
        t_prev = timestamps[i - 1]
        t = timestamps[i]

        TY_prev = df_clean.at[t_prev, "TOTAL_YIELD_CLEAN"]
        TY_now = df_clean.at[t, "TOTAL_YIELD"]
        DY_prev = df_clean.at[t_prev, "DAILY_YIELD_CLEAN"]
        DY_now = df_clean.at[t, "DAILY_YIELD_CLEAN"]

        if t.date() != t_prev.date():
            df_clean.at[t, "TOTAL_YIELD_CLEAN"] = TY_prev
            continue

        delta_dy = DY_now - DY_prev
        TY_expected = TY_prev + delta_dy

        if TY_now < TY_prev:
            df_clean.at[t, "TOTAL_YIELD_CLEAN"] = TY_expected
        else:
            df_clean.at[t, "TOTAL_YIELD_CLEAN"] = TY_now

    df_clean = df_clean[
        [
            "PLANT_ID", "SOURCE_KEY",
            "AC_CLEAN", "DC_CLEAN",
            "DAILY_YIELD_CLEAN", "TOTAL_YIELD_CLEAN",
            "AMBIENT_TEMPERATURE", "MODULE_TEMPERATURE",
            "IRRADIATION_CLEAN", "NUM_OPT", "NUM_SUBOPT",
        ]
    ]

    df_clean["OPERATING_CONDITION_CLEAN"] = np.where(
        df_clean["NUM_OPT"] > df_clean["NUM_SUBOPT"],
        "Optimal", "Suboptimal"
    )

    df_clean = df_clean.drop(columns=["NUM_OPT", "NUM_SUBOPT"])
    df_ps1[sk] = df_clean

# %% [markdown]
# ##### PLANT 2 CLEANING

# %%
### ============================================
### Plant 2: Clean and merge generation + weather
### ============================================

plant_2 = pd.read_csv(gen_path_2, parse_dates=["DATE_TIME"])
plant_2 = plant_2.drop(columns=["PLANT_ID"])
plant_2.set_index("DATE_TIME", inplace=True)

p2_gp = plant_2.groupby("SOURCE_KEY")
inv_2 = {SOURCE_KEY: group for SOURCE_KEY, group in p2_gp}
source_key_2 = plant_2["SOURCE_KEY"].unique().tolist()

agg_inv_2 = {}
for sk, df_inv in inv_2.items():
    agg_df = df_inv.groupby("DATE_TIME").agg(
        SOURCE_KEY=("SOURCE_KEY", "first"),
        DC_POWER=("DC_POWER", "first"),
        AC_POWER=("AC_POWER", "first"),
        DAILY_YIELD=("DAILY_YIELD", "first"),
        TOTAL_YIELD=("TOTAL_YIELD", "first"),
        NUM_OPT=("Operating_Condition", lambda x: (x == "Optimal").sum()),
        NUM_SUBOPT=("Operating_Condition", lambda x: (x == "Suboptimal").sum()),
    ).reset_index()
    agg_inv_2[sk] = agg_df

df = pd.read_csv(weather_path_2)
df["DATE_TIME"] = pd.to_datetime(df["DATE_TIME"])

day_start = dt.time(6, 0)
day_end = dt.time(18, 30)
df["expected_day"] = df["DATE_TIME"].dt.time.between(day_start, day_end)

df["IRRADIATION_CLEAN"] = df["IRRADIATION"].copy()
df.loc[(~df["expected_day"]) & (df["IRRADIATION_CLEAN"] > 0), "IRRADIATION_CLEAN"] = 0
df.loc[(df["expected_day"]) & (df["IRRADIATION_CLEAN"] == 0), "IRRADIATION_CLEAN"] = float("nan")
df["IRRADIATION_CLEAN"] = df["IRRADIATION_CLEAN"].interpolate(method="linear")
df["IRRADIATION_CLEAN"] = df["IRRADIATION_CLEAN"].fillna(0)

s2_c = df.copy()
s2_c.set_index("DATE_TIME", inplace=True)
s2_c = s2_c.drop(columns=["SOURCE_KEY"])

wea_inv_2 = {}
for sk, df_inv in agg_inv_2.items():
    df_inv = df_inv.set_index("DATE_TIME")
    join_df = df_inv.join(s2_c, how="inner")
    wea_inv_2[sk] = join_df

df_step_1 = {}
for sk, df_inv in wea_inv_2.items():
    df_clean = df_inv.copy()
    df_clean["AC_CLEAN"] = df_clean["AC_POWER"].copy()
    df_clean["DC_CLEAN"] = df_clean["DC_POWER"].copy()

    night_mask = df_clean["IRRADIATION_CLEAN"] == 0
    df_clean.loc[night_mask & (df_clean["AC_CLEAN"] > 0), "AC_CLEAN"] = 0
    df_clean.loc[night_mask & (df_clean["DC_CLEAN"] > 0), "DC_CLEAN"] = 0

    day_mask = df_clean["IRRADIATION_CLEAN"] > 0
    df_clean.loc[day_mask & (df_clean["AC_CLEAN"] == 0), "AC_CLEAN"] = float("nan")
    df_clean.loc[day_mask & (df_clean["DC_CLEAN"] == 0), "DC_CLEAN"] = float("nan")

    df_clean["AC_CLEAN"] = df_clean["AC_CLEAN"].interpolate(method="linear")
    df_clean["DC_CLEAN"] = df_clean["DC_CLEAN"].interpolate(method="linear")
    df_clean["AC_CLEAN"] = df_clean["AC_CLEAN"].fillna(0)
    df_clean["DC_CLEAN"] = df_clean["DC_CLEAN"].fillna(0)

    df_step_1[sk] = df_clean

df_step_2 = {}
for sk, df_inv in df_step_1.items():
    df_clean = df_inv.copy()
    df_clean.index = pd.to_datetime(df_clean.index)
    df_clean["DAILY_YIELD_CLEAN"] = df_clean["DAILY_YIELD"].copy()

    dates = np.unique(df_clean.index.date)
    for d in dates:
        day_mask_full = df_clean.index.date == d
        df_day = df_clean.loc[day_mask_full]
        irr_pos = df_day["IRRADIATION_CLEAN"] > 0

        if not irr_pos.any():
            df_clean.loc[day_mask_full, "DAILY_YIELD_CLEAN"] = 0.0
            continue

        day_start_idx = df_day[irr_pos].index[0]
        day_end_idx = df_day[irr_pos].index[-1]

        night_mask = day_mask_full & (df_clean.index < day_start_idx)
        day_mask = day_mask_full & (df_clean.index >= day_start_idx) & (df_clean.index <= day_end_idx)
        evening_mask = day_mask_full & (df_clean.index > day_end_idx)

        df_clean.loc[night_mask, "DAILY_YIELD_CLEAN"] = 0.0
        val_end = df_clean.at[day_end_idx, "DAILY_YIELD"]
        df_clean.loc[evening_mask, "DAILY_YIELD_CLEAN"] = val_end

        day_idx = df_clean.loc[day_mask].index
        if len(day_idx) == 0:
            continue

        raw_vals = df_clean.loc[day_idx, "DAILY_YIELD_CLEAN"].values.astype(float)
        invalid = np.zeros(len(raw_vals), dtype=bool)
        invalid |= raw_vals <= 0

        if len(raw_vals) > 1:
            drops = np.diff(raw_vals) < 0
            invalid[1:][drops] = True

        df_clean.loc[day_idx[invalid], "DAILY_YIELD_CLEAN"] = np.nan
        df_clean.loc[day_idx, "DAILY_YIELD_CLEAN"] = (
            df_clean.loc[day_idx, "DAILY_YIELD_CLEAN"]
            .interpolate(method="linear", limit_direction="both")
        )

        prev_val = df_clean.at[day_idx[0], "DAILY_YIELD_CLEAN"]
        for t in day_idx[1:]:
            cur = df_clean.at[t, "DAILY_YIELD_CLEAN"]
            if pd.isna(cur) or cur < prev_val:
                df_clean.at[t, "DAILY_YIELD_CLEAN"] = prev_val
            else:
                prev_val = cur

        df_clean.loc[night_mask, "DAILY_YIELD_CLEAN"] = 0.0
        df_clean.loc[evening_mask, "DAILY_YIELD_CLEAN"] = val_end

    df_step_2[sk] = df_clean

df_ps2 = {}
for sk, df_inv in df_step_2.items():
    df_clean = df_inv.copy()
    df_clean["TOTAL_YIELD_CLEAN"] = df_clean["TOTAL_YIELD"].copy()
    timestamps = df_clean.index

    for i in range(1, len(timestamps)):
        t_prev = timestamps[i - 1]
        t = timestamps[i]

        TY_prev = df_clean.at[t_prev, "TOTAL_YIELD_CLEAN"]
        TY_now = df_clean.at[t, "TOTAL_YIELD"]
        DY_prev = df_clean.at[t_prev, "DAILY_YIELD_CLEAN"]
        DY_now = df_clean.at[t, "DAILY_YIELD_CLEAN"]

        if t.date() != t_prev.date():
            df_clean.at[t, "TOTAL_YIELD_CLEAN"] = TY_prev
            continue

        delta_dy = DY_now - DY_prev
        TY_expected = TY_prev + delta_dy

        if TY_now < TY_prev:
            df_clean.at[t, "TOTAL_YIELD_CLEAN"] = TY_expected
        else:
            df_clean.at[t, "TOTAL_YIELD_CLEAN"] = TY_now

    df_clean = df_clean[
        [
            "PLANT_ID", "SOURCE_KEY",
            "AC_CLEAN", "DC_CLEAN",
            "DAILY_YIELD_CLEAN", "TOTAL_YIELD_CLEAN",
            "AMBIENT_TEMPERATURE", "MODULE_TEMPERATURE",
            "IRRADIATION_CLEAN", "NUM_OPT", "NUM_SUBOPT",
        ]
    ]

    df_clean["OPERATING_CONDITION_CLEAN"] = np.where(
        df_clean["NUM_OPT"] > df_clean["NUM_SUBOPT"],
        "Optimal", "Suboptimal"
    )

    df_clean = df_clean.drop(columns=["NUM_OPT", "NUM_SUBOPT"])
    df_ps2[sk] = df_clean

# %% [markdown]
# # Feature Engineering
#
# The following physical and temporal features were engineered:
#
# - **DC/IRRA** and **AC/IRRA**
#   Efficiency-like ratios normalised by irradiance.
#
# - **Temperature Delta**
#   MODULE_TEMPERATURE − AMBIENT_TEMPERATURE.
#
# - **hour_cos**
#   Cosine encoding of hour-of-day to avoid discontinuity near midnight.
#
# These features improve separability for the classifier and strengthen LSTM temporal patterns.

# %% [markdown]
# # Task 4 – Linear SVC Classification
#
# The classification goal is to detect **Suboptimal** operation.
#
# ### Label Strategy
# - Optimal = 0
# - Suboptimal = 1
#
# ### Model Pipeline
# 1. Time-based split: 70% train, 3-day validation window, 10-day test window.
# 2. Median imputation + StandardScaler.
# 3. Linear SVC with class_weight="balanced".
# 4. Threshold selected using validation PR curve:
#    - Threshold chosen to maximise **Suboptimal F1 score**.
#
# ### Evaluation Metrics
# - Precision, Recall, F1 for both classes.
# - PR-AUC (Average Precision) for Suboptimal.
# - Confusion matrix focused on Suboptimal detection.

# %% [markdown]
# ##### SVC MODEL CODE

# %%
### ============================================
### Task 4 – Linear SVC model
### ============================================

def make_label(df):
    return (df["OPERATING_CONDITION_CLEAN"].str.lower() == "suboptimal").astype(int)

def engineer_features(df):
    df = df.groupby("SOURCE_KEY", group_keys=False).apply(lambda g: g.sort_values("DATE_TIME"))
    if {"DC_CLEAN", "IRRADIATION_CLEAN"}.issubset(df.columns):
        df["DC/IRRA"] = df["DC_CLEAN"] / (df["IRRADIATION_CLEAN"] + 1e-3)
    if {"AC_CLEAN", "IRRADIATION_CLEAN"}.issubset(df.columns):
        df["AC/IRRA"] = df["AC_CLEAN"] / (df["IRRADIATION_CLEAN"] + 1e-3)
    if {"MODULE_TEMPERATURE", "AMBIENT_TEMPERATURE"}.issubset(df.columns):
        df["Temp_Delta"] = df["MODULE_TEMPERATURE"] - df["AMBIENT_TEMPERATURE"]
    if "DATE_TIME" in df.columns:
        t = df["DATE_TIME"]
        hour = t.dt.hour + t.dt.minute / 60
        df["hour_cos"] = np.cos(2 * np.pi * hour / 24)
    return df

def assemble_all_from_df_ps(df_ps):
    parts = []
    for key, df_inv in df_ps.items():
        df_inv = df_inv.reset_index().rename(columns=lambda x: "DATE_TIME" if x == "index" else x)
        df_inv["SOURCE_KEY"] = key
        df_inv["DATE_TIME"] = pd.to_datetime(df_inv["DATE_TIME"])
        parts.append(df_inv)

    df_all = pd.concat(parts, ignore_index=True).drop_duplicates()
    m = (~df_all["OPERATING_CONDITION_CLEAN"].isna()) & (~df_all["IRRADIATION_CLEAN"].isna())

    print("\n=== Operating Condition Counts ===")
    counts = df_all["OPERATING_CONDITION_CLEAN"].value_counts()
    print(f"Number of Optimal (0):     {counts.get('Optimal', 0)}")
    print(f"Number of Suboptimal (1):  {counts.get('Suboptimal', 0)}")

    return df_all[m]

def time_split(df, y, test_days=10, val_days=3):
    last = df["DATE_TIME"].max()
    test_start = last - pd.Timedelta(days=test_days)
    val_start = test_start - pd.Timedelta(days=val_days)

    m_te = df["DATE_TIME"] >= test_start
    m_val = (df["DATE_TIME"] >= val_start) & (~m_te)
    m_tr = df["DATE_TIME"] < val_start

    return df[m_tr], df[m_val], df[m_te], y[m_tr], y[m_val], y[m_te]

def make_preprocessor(df):
    drop = ["OPERATING_CONDITION_CLEAN", "DATE_TIME", "PLANT_ID", "SOURCE_KEY"]
    num_cols = [c for c in df.columns if c not in drop and df[c].dtype.kind in "fcui"]

    pre = ColumnTransformer(
        [
            (
                "num",
                Pipeline(
                    [
                        ("imp", SimpleImputer(strategy="median")),
                        ("scaler", StandardScaler()),
                    ]
                ),
                num_cols,
            )
        ]
    )
    return pre

def Suboptimal_f1_threshold(y, score_suboptimal):
    p, r, thr = precision_recall_curve(y, score_suboptimal)
    f1 = 2 * p[1:] * r[1:] / (p[1:] + r[1:] + 1e-12)
    return 0.5 if len(thr) == 0 else float(thr[np.nanargmax(f1)])

def Suboptimal_evaluate(name, y, score_suboptimal, thr, tag):
    pred = (score_suboptimal >= thr).astype(int)
    ap = average_precision_score(y, score_suboptimal)

    print(f"\n==== {name} | {tag} ====")
    print(f"Suboptimal Threshold: {thr:.4f} | PR-AUC: {ap:.4f}")
    print(classification_report(y, pred, digits=3))
    print(confusion_matrix(y, pred))

def run_classification_on_df_ps(df_ps, test_days=10, val_days=3):
    df = assemble_all_from_df_ps(df_ps)
    y = make_label(df)
    df_feat = engineer_features(df)

    X_tr, X_val, X_te, y_tr, y_val, y_te = time_split(df_feat, y, test_days, val_days)
    pre = make_preprocessor(df_feat)

    svc = Pipeline(
        [
            ("pre", pre),
            ("clf", SVC(kernel="linear", class_weight="balanced", probability=True)),
        ]
    )
    svc.fit(X_tr, y_tr)

    val_scores = svc.predict_proba(X_val)[:, 1]
    thr = Suboptimal_f1_threshold(y_val, val_scores)

    test_scores = svc.predict_proba(X_te)[:, 1]
    Suboptimal_evaluate("Linear SVC", y_te, test_scores, thr, "Test Set")

# %% [markdown]
# # Task 6 – LSTM Forecasting (PyTorch)
#
# We forecast AC/DC power **1 hour ahead** using **24 hours of historical data**.
#
# ### Sequence Setup
# - Sampling interval: 15 minutes
# - Window length: 24h → 96 steps
# - Forecast horizon: 1h → 4 steps ahead
# - Target columns: AC_CLEAN, DC_CLEAN
#
# ### Model
# - Single-layer LSTM with 32 hidden units.
# - Final dense layer outputs 1-step regression.
# - Loss: MSE
# - Optimiser: Adam (lr = 1e-3)
# - Early stopping on validation loss (patience = 5).
#
# ### Baselines
# - **Persistence:** last observed value of window.
# - **Moving average:** mean of last 4 time steps.
#
# ### Metrics
# - MAE
# - RMSE
# - Comparison between:
#   - LSTM
#   - Persistence
#   - Moving average
#
# Per-inverter results are aggregated and averaged across plant.

# %% [markdown]
# ##### LSTM MODEL

# %%
### ============================================
### Task 6 – LSTM model (PyTorch)
### ============================================

def make_seq(X, y, L):
    xs, ys = [], []
    for i in range(len(X) - L + 1):
        xs.append(X[i : i + L])
        ys.append(y[i + L - 1])
    return np.array(xs), np.array(ys)

def seq_X_only(arr, L):
    return np.array([arr[i : i + L] for i in range(len(arr) - L + 1)])

def eval_model(y, yhat):
    mae = mean_absolute_error(y, yhat)
    rmse = math.sqrt(mean_squared_error(y, yhat))
    return mae, rmse

class LSTMRegressor(nn.Module):
    def __init__(self, input_dim, hidden_dim=32):
        super().__init__()
        self.lstm = nn.LSTM(input_dim, hidden_dim, batch_first=True)
        self.fc = nn.Linear(hidden_dim, 1)

    def forward(self, x):
        out, _ = self.lstm(x)
        out = out[:, -1, :]
        out = self.fc(out)
        return out

def run_lstm_for_one_df(
    df_raw,
    feature_cols,
    target_col="DC_CLEAN",
    horizon_steps=4,
    window_steps=96,
    inverter_name="",
):
    df = df_raw.sort_index().copy()
    df.index = pd.to_datetime(df.index)
    df["TARGET"] = df[target_col].shift(-horizon_steps)
    df_model = df.dropna(subset=["TARGET"]).copy()

    if len(df_model) <= window_steps + 10:
        print(f"{inverter_name}: insufficient data")
        return None

    n = len(df_model)
    train_end = int(n * 0.7)
    val_end = int(n * 0.85)

    train = df_model.iloc[:train_end]
    val = df_model.iloc[train_end:val_end]
    test = df_model.iloc[val_end:]

    if len(test) <= window_steps:
        print(f"{inverter_name}: test too short")
        return None

    scX = MinMaxScaler().fit(train[feature_cols])
    scY = MinMaxScaler().fit(train[["TARGET"]])

    def scale(df_part):
        return scX.transform(df_part[feature_cols]), scY.transform(df_part[["TARGET"]]).ravel()

    X_train, y_train = scale(train)
    X_val, y_val = scale(val)
    X_test, y_test = scale(test)

    Xtr, ytr = make_seq(X_train, y_train, window_steps)
    Xv, yv = make_seq(X_val, y_val, window_steps)
    Xte, yte = make_seq(X_test, y_test, window_steps)

    test_time = test.index[window_steps - 1 :]

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    Xtr_t = torch.tensor(Xtr, dtype=torch.float32).to(device)
    ytr_t = torch.tensor(ytr, dtype=torch.float32).view(-1, 1).to(device)
    Xv_t = torch.tensor(Xv, dtype=torch.float32).to(device)
    yv_t = torch.tensor(yv, dtype=torch.float32).view(-1, 1).to(device)
    Xte_t = torch.tensor(Xte, dtype=torch.float32).to(device)

    train_loader = DataLoader(TensorDataset(Xtr_t, ytr_t), batch_size=64, shuffle=True)

    model = LSTMRegressor(input_dim=Xtr.shape[2]).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
    loss_fn = nn.MSELoss()

    best_val_loss = float("inf")
    best_state = None
    patience = 5
    streak = 0

    for epoch in range(50):
        model.train()
        for xb, yb in train_loader:
            optimizer.zero_grad()
            pred = model(xb)
            loss = loss_fn(pred, yb)
            loss.backward()
            optimizer.step()

        model.eval()
        with torch.no_grad():
            val_pred = model(Xv_t)
            val_loss = loss_fn(val_pred, yv_t).item()

        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_state = {k: v.cpu().clone() for k, v in model.state_dict().items()}
            streak = 0
        else:
            streak += 1
            if streak >= patience:
                break

    if best_state is not None:
        model.load_state_dict(best_state)
        model.to(device)

    with torch.no_grad():
        pred_test = model(Xte_t).cpu().numpy().ravel()

    y_pred = scY.inverse_transform(pred_test.reshape(-1, 1)).ravel()
    y_true = scY.inverse_transform(yte.reshape(-1, 1)).ravel()

    tgt_raw = test[target_col].values.reshape(-1, 1)
    tgt_seq = seq_X_only(tgt_raw, window_steps)

    persist = tgt_seq[:, -1, 0]
    movavg = tgt_seq[:, -4:, 0].mean(axis=1)

    mae_lstm, rmse_lstm = eval_model(y_true, y_pred)
    mae_pers, rmse_pers = eval_model(y_true, persist)
    mae_ma, rmse_ma = eval_model(y_true, movavg)

    return {
        "inverter": inverter_name,
        "LSTM_MAE": mae_lstm,
        "LSTM_RMSE": rmse_lstm,
        "Pers_MAE": mae_pers,
        "Pers_RMSE": rmse_pers,
        "MA_MAE": mae_ma,
        "MA_RMSE": rmse_ma,
        "y_true": y_true,
        "y_pred_lstm": y_pred,
        "persist": persist,
        "movavg": movavg,
        "test_time": test_time,
        # >>> NEW: information needed to reload the model <<<
        "model_state_dict": model.state_dict(),
        "input_dim": Xtr.shape[2],
        "hidden_dim": model.lstm.hidden_size,
    }
def run_lstm_for_plant(
    df_dict,
    source_keys,
    feature_cols,
    target_type="DC",
    window_hours=24,
    horizon_minutes=60,
    step_minutes=15,
):
    step_per_hour = int(60 / step_minutes)
    window_steps = window_hours * step_per_hour
    horizon_steps = int(horizon_minutes / step_minutes)

    target_col = f"{target_type}_CLEAN"

    all_results = []

    for key in source_keys:
        df_inv = df_dict[key]
        res = run_lstm_for_one_df(
            df_raw=df_inv,
            feature_cols=feature_cols,
            target_col=target_col,
            horizon_steps=horizon_steps,
            window_steps=window_steps,
            inverter_name=key,
        )
        if res is not None:
            all_results.append(res)

    if not all_results:
        return pd.DataFrame(), pd.DataFrame(), []

    results_df = pd.DataFrame(all_results).set_index("inverter")

    avg_results = pd.DataFrame(
        {
            "LSTM_MAE_avg": [results_df["LSTM_MAE"].mean()],
            "LSTM_RMSE_avg": [results_df["LSTM_RMSE"].mean()],
            "Pers_MAE_avg": [results_df["Pers_MAE"].mean()],
            "Pers_RMSE_avg": [results_df["Pers_RMSE"].mean()],
            "MA_MAE_avg": [results_df["MA_MAE"].mean()],
            "MA_RMSE_avg": [results_df["MA_RMSE"].mean()],
        }
    )

    return results_df, avg_results, all_results

# %% [markdown]
# # RUNNING ALL MODELS

# %%
### ============================================
### Run SVC and LSTM for Plants 1 and 2
### ============================================

# ---------------------------
# Task 4 – Linear SVC
# ---------------------------
run_classification_on_df_ps(df_ps1)
run_classification_on_df_ps(df_ps2)

# ---------------------------
# Task 6 – LSTM Forecasting
# ---------------------------
feature_cols = [
    "AC_CLEAN",
    "DC_CLEAN",
    "IRRADIATION_CLEAN",
    "AMBIENT_TEMPERATURE",
    "MODULE_TEMPERATURE",
]

# Plant 1 – AC
results_p1_ac_df, avg_p1_ac_df, raw_p1_ac = run_lstm_for_plant(
    df_dict=df_ps1,
    source_keys=source_key_1,
    feature_cols=feature_cols,
    target_type="AC",
    window_hours=24,
    horizon_minutes=60,
    step_minutes=15,
)
display(results_p1_ac_df)
display(avg_p1_ac_df)

# Plant 1 – DC
results_p1_dc_df, avg_p1_dc_df, raw_p1_dc = run_lstm_for_plant(
    df_dict=df_ps1,
    source_keys=source_key_1,
    feature_cols=feature_cols,
    target_type="DC",
    window_hours=24,
    horizon_minutes=60,
    step_minutes=15,
)
display(results_p1_dc_df)
display(avg_p1_dc_df)

# Plant 2 – AC
results_p2_ac_df, avg_p2_ac_df, raw_p2_ac = run_lstm_for_plant(
    df_dict=df_ps2,
    source_keys=source_key_2,
    feature_cols=feature_cols,
    target_type="AC",
    window_hours=24,
    horizon_minutes=60,
    step_minutes=15,
)
display(results_p2_ac_df)
display(avg_p2_ac_df)

# Plant 2 – DC
results_p2_dc_df, avg_p2_dc_df, raw_p2_dc = run_lstm_for_plant(
    df_dict=df_ps2,
    source_keys=source_key_2,
    feature_cols=feature_cols,
    target_type="DC",
    window_hours=24,
    horizon_minutes=60,
    step_minutes=15,
)
display(results_p2_dc_df)
display(avg_p2_dc_df)
# Out:
# === Operating Condition Counts ===
# Number of Optimal (0):     7656
# Number of Suboptimal (1):  38024
# C:\Users\B.KING\AppData\Local\Temp\ipykernel_34228\4050243800.py:9: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby
DatetimeIndex(['2020-06-15 16:45:00', '2020-06...
# 7JYdWkrLSPkdwr4  DatetimeIndex(['2020-06-15 16:00:00', '2020-06...
# McdE0feGgRqW7Ca  DatetimeIndex(['2020-06-15 16:30:00', '2020-06...
# VHMLBKoKgIrUVDU  DatetimeIndex(['2020-06-15 16:00:00', '2020-06...
# WRmjgnKYAwPKWDb  DatetimeIndex(['2020-06-15 16:45:00', '2020-06...
# ZnxXDlPa8U1GXgE  DatetimeIndex(['2020-06-15 16:15:00', '2020-06...
# ZoEaEvLYb1n2sOq  DatetimeIndex(['2020-06-15 16:30:00', '2020-06...
# adLQvlD726eNBSB  DatetimeIndex(['2020-06-15 16:45:00', '2020-06...
# bvBOhCH3iADSZry  DatetimeIndex(['2020-06-15 15:30:00', '2020-06...
# iCRJl6heRkivqQ3  DatetimeIndex(['2020-06-15 16:30:00', '2020-06...
# ih0vzX44oOqAx2f  DatetimeIndex(['2020-06-15 16:15:00', '2020-06...
# pkci93gMrogZuBj  DatetimeIndex(['2020-06-15 16:30:00', '2020-06...
# rGa61gmuvPhdLxV  DatetimeIndex(['2020-06-15 16:30:00', '2020-06...
# sjndEbLyjtCKgGv  DatetimeIndex(['2020-06-15 16:30:00', '2020-06...
# uHbuxQJl8lW7ozc  DatetimeIndex(['2020-06-15 16:30:00', '2020-06...
# wCURE6d3bPkepu2  DatetimeIndex(['2020-06-15 16:30:00', '2020-06...
# z9Y9gH1T5YWrNuG  DatetimeIndex(['2020-06-15 16:30:00', '2020-06...
# zBIq5rxdHJRwDNY  DatetimeIndex(['2020-06-15 16:45:00', '2020-06...
# zVJPv84UY57bAof  DatetimeIndex(['2020-06-15 16:30:00', '2020-06...
# YxYtjZvoooNbGkE  DatetimeIndex(['2020-06-15 17:15:00', '2020-06...
#
#                                                   model_state_dict  input_dim  \
# inverter
# 1BY6WEcLGh8j5v7  {'lstm.weight_ih_l0': [[tensor(0.1637), tensor...          5
# 1IF53ai7Xc0U56Y  {'lstm.weight_ih_l0': [[tensor(0.2349), tensor...          5
# 3PZuoBAID5Wc2HD  {'lstm.weight_ih_l0': [[tensor(-0.0551), tenso...          5
# 7JYdWkrLSPkdwr4  {'lstm.weight_ih_l0': [[tensor(-0.1004), tenso...          5
# McdE0feGgRqW7Ca  {'lstm.weight_ih_l0': [[tensor(0.2546), tensor...          5
# VHMLBKoKgIrUVDU  {'lstm.weight_ih_l0': [[tensor(-0.1565), tenso...          5
# WRmjgnKYAwPKWDb  {'lstm.weight_ih_l0': [[tensor(0.1001), tensor...          5
# ZnxXDlPa8U1GXgE  {'lstm.weight_ih_l0': [[tensor(0.0734), tensor...          5
# ZoEaEvLYb1n2sOq  {'lstm.weight_ih_l0': [[tensor(0.1763), tensor...          5
# adLQvlD726eNBSB  {'lstm.weight_ih_l0': [[tensor(-0.0906), tenso...          5
# bvBOhCH3iADSZry  {'lstm.weight_ih_l0': [[tensor(-0.0306), tenso...          5
# iCRJl6heRkivqQ3  {'lstm.weight_ih_l0': [[tensor(-0.1023), tenso...          5
# ih0vzX44oOqAx2f  {'lstm.weight_ih_l0': [[tensor(-0.3388), tenso...          5
# pkci93gMrogZuBj  {'lstm.weight_ih_l0': [[tensor(0.0107), tensor...          5
# rGa61gmuvPhdLxV  {'lstm.weight_ih_l0': [[tensor(0.0843), tensor...          5
# sjndEbLyjtCKgGv  {'lstm.weight_ih_l0': [[tensor(0.0270), tensor...          5
# uHbuxQJl8lW7ozc  {'lstm.weight_ih_l0': [[tensor(0.0839), tensor...          5
# wCURE6d3bPkepu2  {'lstm.weight_ih_l0': [[tensor(0.0128), tensor...          5
# z9Y9gH1T5YWrNuG  {'lstm.weight_ih_l0': [[tensor(0.1264), tensor...          5
# zBIq5rxdHJRwDNY  {'lstm.weight_ih_l0': [[tensor(-0.0630), tenso...          5
DatetimeIndex(['2020-06-15 16:45:00', '2020-06...
# 3PZuoBAID5Wc2HD  DatetimeIndex(['2020-06-15 16:45:00', '2020-06...
# 7JYdWkrLSPkdwr4  DatetimeIndex(['2020-06-15 16:00:00', '2020-06...
# McdE0feGgRqW7Ca  DatetimeIndex(['2020-06-15 16:30:00', '2020-06...
# VHMLBKoKgIrUVDU  DatetimeIndex(['2020-06-15 16:00:00', '2020-06...
# WRmjgnKYAwPKWDb  DatetimeIndex(['2020-06-15 16:45:00', '2020-06...
# ZnxXDlPa8U1GXgE  DatetimeIndex(['2020-06-15 16:15:00', '2020-06...
# ZoEaEvLYb1n2sOq  DatetimeIndex(['2020-06-15 16:30:00', '2020-06...
# adLQvlD726eNBSB  DatetimeIndex(['2020-06-15 16:45:00', '2020-06...
# bvBOhCH3iADSZry  DatetimeIndex(['2020-06-15 15:30:00', '2020-06...
# iCRJl6heRkivqQ3  DatetimeIndex(['2020-06-15 16:30:00', '2020-06...
# ih0vzX44oOqAx2f  DatetimeIndex(['2020-06-15 16:15:00', '2020-06...
# pkci93gMrogZuBj  DatetimeIndex(['2020-06-15 16:30:00', '2020-06...
# rGa61gmuvPhdLxV  DatetimeIndex(['2020-06-15 16:30:00', '2020-06...
# sjndEbLyjtCKgGv  DatetimeIndex(['2020-06-15 16:30:00', '2020-06...
# uHbuxQJl8lW7ozc  DatetimeIndex(['2020-06-15 16:30:00', '2020-06...
# wCURE6d3bPkepu2  DatetimeIndex(['2020-06-15 16:30:00', '2020-06...
# z9Y9gH1T5YWrNuG  DatetimeIndex(['2020-06-15 16:30:00', '2020-06...
# zBIq5rxdHJRwDNY  DatetimeIndex(['2020-06-15 16:45:00', '2020-06...
# zVJPv84UY57bAof  DatetimeIndex(['2020-06-15 16:30:00', '2020-06...
# YxYtjZvoooNbGkE  DatetimeIndex(['2020-06-15 17:15:00', '2020-06...
#
#                                                   model_state_dict  input_dim  \
# inverter
# 1BY6WEcLGh8j5v7  {'lstm.weight_ih_l0': [[tensor(0.0641), tensor...          5
# 1IF53ai7Xc0U56Y  {'lstm.weight_ih_l0': [[tensor(-0.0751), tenso...          5
# 3PZuoBAID5Wc2HD  {'lstm.weight_ih_l0': [[tensor(0.1147), tensor...          5
# 7JYdWkrLSPkdwr4  {'lstm.weight_ih_l0': [[tensor(0.0025), tensor...          5
# McdE0feGgRqW7Ca  {'lstm.weight_ih_l0': [[tensor(0.1871), tensor...          5
# VHMLBKoKgIrUVDU  {'lstm.weight_ih_l0': [[tensor(0.0414), tensor...          5
# WRmjgnKYAwPKWDb  {'lstm.weight_ih_l0': [[tensor(0.0741), tensor...          5
# ZnxXDlPa8U1GXgE  {'lstm.weight_ih_l0': [[tensor(-0.0409), tenso...          5
# ZoEaEvLYb1n2sOq  {'lstm.weight_ih_l0': [[tensor(-0.1403), tenso...          5
# adLQvlD726eNBSB  {'lstm.weight_ih_l0': [[tensor(0.2349), tensor...          5
# bvBOhCH3iADSZry  {'lstm.weight_ih_l0': [[tensor(-0.1200), tenso...          5
# iCRJl6heRkivqQ3  {'lstm.weight_ih_l0': [[tensor(0.0298), tensor...          5
# ih0vzX44oOqAx2f  {'lstm.weight_ih_l0': [[tensor(-0.0095), tenso...          5
# pkci93gMrogZuBj  {'lstm.weight_ih_l0': [[tensor(0.0585), tensor...          5
# rGa61gmuvPhdLxV  {'lstm.weight_ih_l0': [[tensor(-0.0559), tenso...          5
DatetimeIndex(['2020-06-13 20:30:00', '2020-06...
# q49J1IKaHRwDQnt  DatetimeIndex(['2020-06-13 20:30:00', '2020-06...
# rrq4fwE8jgrTyWY  DatetimeIndex(['2020-06-13 20:30:00', '2020-06...
# vOuJvMaM2sgwLmb  DatetimeIndex(['2020-06-13 20:30:00', '2020-06...
# xMbIugepa2P7lBB  DatetimeIndex(['2020-06-15 06:30:00', '2020-06...
# xoJJ8DcxJEcupym  DatetimeIndex(['2020-06-13 20:30:00', '2020-06...
#
#                                                   model_state_dict  input_dim  \
# inverter
# 4UPUqMRk7TRMgml  {'lstm.weight_ih_l0': [[tensor(-0.0851), tenso...          5
# 81aHJ1q11NBPMrL  {'lstm.weight_ih_l0': [[tensor(-0.0500), tenso...          5
# 9kRcWv60rDACzjR  {'lstm.weight_ih_l0': [[tensor(0.0096), tensor...          5
# Et9kgGMDl729KT4  {'lstm.weight_ih_l0': [[tensor(-0.0613), tenso...          5
# IQ2d7wF4YD8zU1Q  {'lstm.weight_ih_l0': [[tensor(0.1666), tensor...          5
# LYwnQax7tkwH5Cb  {'lstm.weight_ih_l0': [[tensor(-0.0337), tenso...          5
# LlT2YUhhzqhg5Sw  {'lstm.weight_ih_l0': [[tensor(0.1348), tensor...          5
# Mx2yZCDsyf6DPfv  {'lstm.weight_ih_l0': [[tensor(-0.2536), tenso...          5
# NgDl19wMapZy17u  {'lstm.weight_ih_l0': [[tensor(-0.1241), tenso...          5
# PeE6FRyGXUgsRhN  {'lstm.weight_ih_l0': [[tensor(-0.0998), tenso...          5
# Qf4GUc1pJu5T6c6  {'lstm.weight_ih_l0': [[tensor(0.0080), tensor...          5
# Quc1TzYxW2pYoWX  {'lstm.weight_ih_l0': [[tensor(0.0734), tensor...          5
# V94E5Ben1TlhnDV  {'lstm.weight_ih_l0': [[tensor(-0.0747), tenso...          5
# WcxssY2VbP4hApt  {'lstm.weight_ih_l0': [[tensor(-0.0281), tenso...          5
# mqwcsP2rE7J0TFp  {'lstm.weight_ih_l0': [[tensor(-0.0904), tenso...          5
# oZ35aAeoifZaQzV  {'lstm.weight_ih_l0': [[tensor(0.1757), tensor...          5
# oZZkBaNadn6DNKz  {'lstm.weight_ih_l0': [[tensor(0.0048), tensor...          5
# q49J1IKaHRwDQnt  {'lstm.weight_ih_l0': [[tensor(0.1884), tensor...          5
# rrq4fwE8jgrTyWY  {'lstm.weight_ih_l0': [[tensor(0.0979), tensor...          5
# vOuJvMaM2sgwLmb  {'lstm.weight_ih_l0': [[tensor(0.0813), tensor...          5
# xMbIugepa2P7lBB  {'lstm.weight_ih_l0': [[tensor(-0.0519), tenso...          5
# xoJJ8DcxJEcupym  {'lstm.weight_ih_l0': [[tensor(-0.0996), tenso...          5
#
#                  hidden_dim
# inverter
# 4UPUqMRk7TRMgml          32
# 81aHJ1q11NBPMrL          32
# 9kRcWv60rDACzjR          32
# Et9kgGMDl729KT4          32
# IQ2d7wF4YD8zU1Q          32
# LYwnQax7tkwH5Cb          32
# LlT2YUhhzqhg5Sw          32
# Mx2yZCDsyf6DPfv          32
# NgDl19wMapZy17u          32
# PeE6FRyGXUgsRhN          32
# Qf4GUc1pJu5T6c6          32
# Quc1TzYxW2pYoWX          32
# V94E5Ben1TlhnDV          32
# WcxssY2VbP4hApt          32
# mqwcsP2rE7J0TFp          32
# oZ35aAeoifZaQzV          32
# oZZkBaNadn6DNKz          32
# q49J1IKaHRwDQnt          32
# rrq4fwE8jgrTyWY          32
# vOuJvMaM2sgwLmb          32
# xMbIugepa2P7lBB          32
# xoJJ8DcxJEcupym          32
#    LSTM_MAE_avg  LSTM_RMSE_avg  Pers_MAE_avg  Pers_RMSE_avg  MA_MAE_avg  \
# 0     99.078671     150.564232    100.432793     172.474896  108.662329
#
#    MA_RMSE_avg
# 0    175.14957

# %%
# ============================================================
# SAVE FORECASTING RESULTS + TRAINED LSTM MODELS
# ============================================================

####################################################################################################################################################

# Change here 

save_folder = r"C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model"

####################################################################################################################################################

os.makedirs(save_folder, exist_ok=True)

# ---------- 4.1 Save all results in one PKL ----------

save_path = os.path.join(save_folder, "LSTM Forecasting Model.pkl")

LSTM_results = {
    "Plant1_AC": {
        "per_inverter": results_p1_ac_df,
        "average": avg_p1_ac_df,
        "raw_outputs": raw_p1_ac,
    },
    "Plant1_DC": {
        "per_inverter": results_p1_dc_df,
        "average": avg_p1_dc_df,
        "raw_outputs": raw_p1_dc,
    },
    "Plant2_AC": {
        "per_inverter": results_p2_ac_df,
        "average": avg_p2_ac_df,
        "raw_outputs": raw_p2_ac,
    },
    "Plant2_DC": {
        "per_inverter": results_p2_dc_df,
        "average": avg_p2_dc_df,
        "raw_outputs": raw_p2_dc,
    },
}

with open(save_path, "wb") as f:
    pickle.dump(LSTM_results, f)

print(f"\n✅ LSTM forecasting results saved to:\n{save_path}")

# ---------- 4.2 Save each trained LSTM model as a .pt file ----------

model_dir = os.path.join(save_folder, "models")
os.makedirs(model_dir, exist_ok=True)

def save_model_group(results_list, plant_name, target_type):
    for entry in results_list:
        inv = entry["inverter"]
        state = entry["model_state_dict"]
        input_dim = entry["input_dim"]
        hidden_dim = entry["hidden_dim"]

        filename = f"{plant_name}_{target_type}_{inv}_LSTM.pt"
        file_path = os.path.join(model_dir, filename)

        torch.save(
            {
                "state_dict": state,
                "input_dim": input_dim,
                "hidden_dim": hidden_dim,
            },
            file_path,
        )

        print(f"📁 Saved model → {file_path}")

# Save Plant 1 models
save_model_group(raw_p1_ac, "Plant1", "AC")
save_model_group(raw_p1_dc, "Plant1", "DC")

# Save Plant 2 models
save_model_group(raw_p2_ac, "Plant2", "AC")
save_model_group(raw_p2_dc, "Plant2", "DC")

print("\n✅ All trained LSTM models saved successfully!")
# Out:
# ✅ LSTM forecasting results saved to:
# C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\LSTM Forecasting Model.pkl
# 📁 Saved model → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\models\Plant1_AC_1BY6WEcLGh8j5v7_LSTM.pt
# 📁 Saved model → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\models\Plant1_AC_1IF53ai7Xc0U56Y_LSTM.pt
# 📁 Saved model → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\models\Plant1_AC_3PZuoBAID5Wc2HD_LSTM.pt
# 📁 Saved model → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\models\Plant1_AC_7JYdWkrLSPkdwr4_LSTM.pt
# 📁 Saved model → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\models\Plant1_AC_McdE0feGgRqW7Ca_LSTM.pt
# 📁 Saved model → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\models\Plant1_AC_VHMLBKoKgIrUVDU_LSTM.pt
# 📁 Saved model → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\models\Plant1_AC_WRmjgnKYAwPKWDb_LSTM.pt
# 📁 Saved model → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\models\Plant1_AC_ZnxXDlPa8U1GXgE_LSTM.pt
# 📁 Saved model → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\models\Plant1_AC_ZoEaEvLYb1n2sOq_LSTM.pt
# 📁 Saved model → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\models\Plant1_AC_adLQvlD726eNBSB_LSTM.pt
# 📁 Saved model → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\models\Plant1_AC_bvBOhCH3iADSZry_LSTM.pt
# 📁 Saved model → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\models\Plant1_AC_iCRJl6heRkivqQ3_LSTM.pt
# 📁 Saved model → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\models\Plant1_AC_ih0vzX44oOqAx2f_LSTM.pt
# 📁 Saved model → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\models\Plant1_AC_pkci93gMrogZuBj_LSTM.pt
# 📁 Saved model → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\models\Plant1_AC_rGa61gmuvPhdLxV_LSTM.pt
# 📁 Saved model → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\models\Plant1_AC
#
# Reason:
# Longer lookback windows capture diurnal patterns and slow weather transitions, improving model accuracy for both 1-hour and 3-hour forecasts.
#
# Hidden Size
#
# We use a single-layer LSTM with 32 hidden units. This choice balances model complexity, training efficiency, and overfitting avoidance.
# PV power time series are relatively smooth, dominated by irradiance patterns rather than high-frequency noise. Thus a very large LSTM (e.g., 128+ units) is unnecessary and may overfit sensor noise or sudden irradiance spikes. A 32-unit layer provides enough representational capacity to capture nonlinear interactions among irradiance, temperature, and power output, while remaining computationally efficient.
#
# Reason:
# A hidden size of 32 provides sufficient learning capacity without overfitting and allows efficient training across many inverters.
#
# Loss Function & Optimizer
#
# We employ Mean Squared Error (MSE) as the loss function.MSE penalizes large errors more strongly, which is especially important in PV forecasting because large deviations (e.g., cloud-induced power drops) can severely affect plant scheduling, reserve management, and inverter operation. Compared with MAE, MSE is more sensitive to sudden irradiance changes, making it suitable for operational reliability.
#
# Reason:
# MSE emphasizes large deviations and aligns with engineering requirements for stable power forecasting.
#
# The model is trained using the Adam optimizer, which adapts learning rates dynamically.
#
# Reason:
# Adam is the most efficient and robust choice for sequence models like LSTM.

# %%
def visualize_lstm_results(
    df_dict,
    results_df,
    all_results,
    target_type="DC",
    power_threshold=50.0,
    figsize=(16, 6),
    plant_name="Plant"
):
    """
    Visualize AND SAVE LSTM forecast results for each inverter.

    Parameters
    ----------
    df_dict : dict
        Dictionary of inverter dataframes (df_ps1 or df_ps2).
    results_df : DataFrame
        Per-inverter summary metrics returned by run_lstm_for_plant().
    all_results : list of dict
        Raw results list returned by run_lstm_for_plant().
    target_type : str
        "AC" or "DC".
    power_threshold : float
        Filter out low-power nighttime noise.
    figsize : tuple
        Figure size.
    plant_name : str
        "Plant1" or "Plant2".
    """

    # ------------------------
    # Create output folder
    # ------------------------

    ####################################################################################################################################################
    
    # Change here 

    save_dir = r"C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots"

    #####################################################################################################################################################
    
    os.makedirs(save_dir, exist_ok=True)

    print(f"\n==============================")
    print(f" Saving LSTM Plots for {plant_name} ({target_type})")
    print(f"==============================\n")

    for entry in all_results:
        inv = entry["inverter"]

        y_true = entry["y_true"]
        y_pred = entry["y_pred_lstm"]
        persist = entry["persist"]
        movavg = entry["movavg"]
        time_index = entry["test_time"]

        # Filter small values
        valid = y_true > power_threshold
        if valid.sum() < 5:
            print(f"Skipping {inv}: insufficient high-power samples.")
            continue

        t = time_index[valid]
        yt = y_true[valid]
        yp = y_pred[valid]
        yp_persist = persist[valid]
        yp_ma = movavg[valid]

        # ------------------------------
        # Plot 1: True vs Predicted
        # ------------------------------
        plt.figure(figsize=figsize)
        plt.plot(t, yt, label="True Power", linewidth=2)
        plt.plot(t, yp, label="LSTM Forecast", alpha=0.85)
        plt.plot(t, yp_persist, label="Persistence", linestyle="--", alpha=0.7)
        plt.plot(t, yp_ma, label="Moving Avg", linestyle="--", alpha=0.7)

        plt.title(f"{plant_name} – {inv} – {target_type} Forecast")
        plt.xlabel("Time")
        plt.ylabel(f"{target_type} Power")
        plt.legend()
        plt.grid(True)
        plt.tight_layout()

        # Save forecast plot
        fpath1 = os.path.join(save_dir, f"{plant_name}_{target_type}_{inv}_forecast.png")
        plt.savefig(fpath1, dpi=200)
        plt.close()

        # ------------------------------
        # Plot 2: Error plot
        # ------------------------------
        errors = yt - yp

        plt.figure(figsize=figsize)
        plt.plot(t, errors, label="LSTM Error", linewidth=1.5)
        plt.axhline(0, color="black", linewidth=1)
        plt.title(f"{plant_name} – {inv} – {target_type} Error")
        plt.xlabel("Time")
        plt.ylabel("Error (True - Predicted)")
        plt.grid(True)
        plt.tight_layout()

        # Save error plot
        fpath2 = os.path.join(save_dir, f"{plant_name}_{target_type}_{inv}_error.png")
        plt.savefig(fpath2, dpi=200)
        plt.close()

        print(f"📁 Saved plots for {inv}:")
        print(f"   → {fpath1}")
        print(f"   → {fpath2}")

        # ------------------------------
        # Print Metrics
        # ------------------------------
        print(f"\n----- Metrics for {inv} ({target_type}) -----")
        print(results_df.loc[inv][[
            "LSTM_MAE", "LSTM_RMSE",
            "Pers_MAE", "Pers_RMSE",
            "MA_MAE", "MA_RMSE"
        ]])
        print("\n----------------------------------------------\n")

# %% [markdown]
# ### Plant 1 - DC

# %%
visualize_lstm_results(
    df_ps1,
    results_p1_dc_df,
    raw_p1_dc,
    "DC",
    50,
    plant_name="Plant1"
)
# Out:
# ==============================
#  Saving LSTM Plots for Plant1 (DC)
# ==============================
#
# 📁 Saved plots for 1BY6WEcLGh8j5v7:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_DC_1BY6WEcLGh8j5v7_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_DC_1BY6WEcLGh8j5v7_error.png
#
# ----- Metrics for 1BY6WEcLGh8j5v7 (DC) -----
# LSTM_MAE       738.29951
# LSTM_RMSE    1167.665747
# Pers_MAE      926.993588
# Pers_RMSE    1623.764202
# MA_MAE       1132.338981
# MA_RMSE      1789.851329
# Name: 1BY6WEcLGh8j5v7, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for 1IF53ai7Xc0U56Y:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_DC_1IF53ai7Xc0U56Y_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_DC_1IF53ai7Xc0U56Y_error.png
#
# ----- Metrics for 1IF53ai7Xc0U56Y (DC) -----
# LSTM_MAE      936.827899
# LSTM_RMSE    1370.205997
# Pers_MAE      997.469269
# Pers_RMSE    1773.893681
# MA_MAE       1220.472467
# MA_RMSE       1964.25377
# Name: 1IF53ai7Xc0U56Y, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for 3PZuoBAID5Wc2HD:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_DC_3PZuoBAID5Wc2HD_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_DC_3PZuoBAID5Wc2HD_error.png
#
# ----- Metrics for 3PZuoBAID5Wc2HD (DC) -----
# LSTM_MAE      910.571382
# LSTM_RMSE    1388.776098
# Pers_MAE      994.445598
# Pers_RMSE    1753.341722
# MA_MAE        1186.86738
# MA_RMSE       1924.15658
# Name: 3PZuoBAID5Wc2HD, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for 7JYdWkrLSPkdwr4:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_DC_7JYdWkrLSPkdwr4_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_DC_7JYdWkrLSPkdwr4_error.png
#
# ----- Metrics for 7JYdWkrLSPkdwr4 (DC) -----
# LSTM_MAE       798.50136
# LSTM_RMSE    1354.681321
# Pers_MAE      982.065777
# Pers_RMSE    1726.255801
# MA_MAE        1199.74744
# MA_RMSE      1900.552103
# Name: 7JYdWkrLSPkdwr4, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for McdE0feGgRqW7Ca:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_DC_McdE0feGgRqW7Ca_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_DC_McdE0feGgRqW7Ca_error.png
#
# ----- Metrics for McdE0feGgRqW7Ca (DC) -----
# LSTM_MAE      925.873609
# LSTM_RMSE    1439.746177
# Pers_MAE     1004.310268
# Pers_RMSE    1800.219247
# MA_MAE       1239.378514
# MA_RMSE      1988.950288
# Name: McdE0feGgRqW7Ca, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for VHMLBKoKgIrUVDU:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_DC_VHMLBKoKgIrUVDU_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_DC_VHMLBKoKgIrUVDU_error.png
#
# ----- Metrics for VHMLBKoKgIrUVDU (DC) -----
# LSTM_MAE       912.50359
# LSTM_RMSE    1459.272029
# Pers_MAE     1015.591334
# Pers_RMSE     1770.16782
# MA_MAE       1231.175766
# MA_RMSE      1951.187761
# Name: VHMLBKoKgIrUVDU, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for WRmjgnKYAwPKWDb:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_DC_WRmjgnKYAwPKWDb_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_DC_WRmjgnKYAwPKWDb_error.png
#
# ----- Metrics for WRmjgnKYAwPKWDb (DC) -----
# LSTM_MAE      829.790033
# LSTM_RMSE    1329.081374
# Pers_MAE      988.256312
# Pers_RMSE    1738.859633
# MA_MAE       1171.738808
# MA_RMSE      1909.568256
# Name: WRmjgnKYAwPKWDb, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for ZnxXDlPa8U1GXgE:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_DC_ZnxXDlPa8U1GXgE_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_DC_ZnxXDlPa8U1GXgE_error.png
#
# ----- Metrics for ZnxXDlPa8U1GXgE (DC) -----
# LSTM_MAE      880.725441
# LSTM_RMSE    1421.028498
# Pers_MAE      995.683262
# Pers_RMSE    1764.896396
# MA_MAE       1218.282299
# MA_RMSE      1946.850597
# Name: ZnxXDlPa8U1GXgE, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for ZoEaEvLYb1n2sOq:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_DC_ZoEaEvLYb1n2sOq_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_DC_ZoEaEvLYb1n2sOq_error.png
#
# ----- Metrics for ZoEaEvLYb1n2sOq (DC) -----
# LSTM_MAE      910.528472
# LSTM_RMSE    1402.447866
# Pers_MAE      986.947669
# Pers_RMSE     1758.96382
# MA_MAE       1215.307044
# MA_RMSE      1946.203573
# Name: ZoEaEvLYb1n2sOq, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for adLQvlD726eNBSB:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_DC_adLQvlD726eNBSB_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_DC_adLQvlD726eNBSB_error.png
#
# ----- Metrics for adLQvlD726eNBSB (DC) -----
# LSTM_MAE      899.319959
# LSTM_RMSE    1357.064722
# Pers_MAE     1016.715947
# Pers_RMSE    1798.925054
# MA_MAE       1231.123339
# MA_RMSE      1982.464182
# Name: adLQvlD726eNBSB, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for bvBOhCH3iADSZry:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_DC_bvBOhCH3iADSZry_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_DC_bvBOhCH3iADSZry_error.png
#
# ----- Metrics for bvBOhCH3iADSZry (DC) -----
# LSTM_MAE      748.367202
# LSTM_RMSE    1206.343463
# Pers_MAE      909.062744
# Pers_RMSE    1582.740892
# MA_MAE       1109.105946
# MA_RMSE      1754.512286
# Name: bvBOhCH3iADSZry, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for iCRJl6heRkivqQ3:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_DC_iCRJl6heRkivqQ3_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_DC_iCRJl6heRkivqQ3_error.png
#
# ----- Metrics for iCRJl6heRkivqQ3 (DC) -----
# LSTM_MAE      807.581055
# LSTM_RMSE    1337.384083
# Pers_MAE      999.501075
# Pers_RMSE     1785.38281
# MA_MAE       1222.575107
# MA_RMSE       1961.21679
# Name: iCRJl6heRkivqQ3, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for ih0vzX44oOqAx2f:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_DC_ih0vzX44oOqAx2f_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_DC_ih0vzX44oOqAx2f_error.png
#
# ----- Metrics for ih0vzX44oOqAx2f (DC) -----
# LSTM_MAE      836.238374
# LSTM_RMSE    1321.248263
# Pers_MAE      971.953012
# Pers_RMSE    1728.829306
# MA_MAE       1188.818878
# MA_RMSE      1903.008873
# Name: ih0vzX44oOqAx2f, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for pkci93gMrogZuBj:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_DC_pkci93gMrogZuBj_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_DC_pkci93gMrogZuBj_error.png
#
# ----- Metrics for pkci93gMrogZuBj (DC) -----
# LSTM_MAE      874.702905
# LSTM_RMSE    1347.493021
# Pers_MAE     1001.749008
# Pers_RMSE    1806.234385
# MA_MAE       1218.279514
# MA_RMSE      1967.725511
# Name: pkci93gMrogZuBj, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for rGa61gmuvPhdLxV:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_DC_rGa61gmuvPhdLxV_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_DC_rGa61gmuvPhdLxV_error.png
#
# ----- Metrics for rGa61gmuvPhdLxV (DC) -----
# LSTM_MAE      866.574712
# LSTM_RMSE    1402.369105
# Pers_MAE     1001.286872
# Pers_RMSE    1783.170386
# MA_MAE       1223.429605
# MA_RMSE      1964.478499
# Name: rGa61gmuvPhdLxV, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for sjndEbLyjtCKgGv:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_DC_sjndEbLyjtCKgGv_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_DC_sjndEbLyjtCKgGv_error.png
#
# ----- Metrics for sjndEbLyjtCKgGv (DC) -----
# LSTM_MAE      825.596032
# LSTM_RMSE    1388.185958
# Pers_MAE      989.163112
# Pers_RMSE    1769.660653
# MA_MAE       1215.642981
# MA_RMSE      1950.006389
# Name: sjndEbLyjtCKgGv, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for uHbuxQJl8lW7ozc:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_DC_uHbuxQJl8lW7ozc_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_DC_uHbuxQJl8lW7ozc_error.png
#
# ----- Metrics for uHbuxQJl8lW7ozc (DC) -----
# LSTM_MAE      840.991297
# LSTM_RMSE    1372.081631
# Pers_MAE     1002.262235
# Pers_RMSE    1805.663727
# MA_MAE       1228.031953
# MA_RMSE      1977.784841
# Name: uHbuxQJl8lW7ozc, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for wCURE6d3bPkepu2:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_DC_wCURE6d3bPkepu2_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_DC_wCURE6d3bPkepu2_error.png
#
# ----- Metrics for wCURE6d3bPkepu2 (DC) -----
# LSTM_MAE      849.291257
# LSTM_RMSE    1434.725206
# Pers_MAE     1001.092097
# Pers_RMSE    1778.251292
# MA_MAE       1223.003204
# MA_RMSE      1955.707343
# Name: wCURE6d3bPkepu2, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for z9Y9gH1T5YWrNuG:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_DC_z9Y9gH1T5YWrNuG_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_DC_z9Y9gH1T5YWrNuG_error.png
#
# ----- Metrics for z9Y9gH1T5YWrNuG (DC) -----
# LSTM_MAE      860.590267
# LSTM_RMSE    1372.783111
# Pers_MAE      978.886657
# Pers_RMSE     1735.67953
# MA_MAE       1200.827464
# MA_RMSE      1920.060017
# Name: z9Y9gH1T5YWrNuG, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for zBIq5rxdHJRwDNY:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_DC_zBIq5rxdHJRwDNY_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_DC_zBIq5rxdHJRwDNY_error.png
#
# ----- Metrics for zBIq5rxdHJRwDNY (DC) -----
# LSTM_MAE     1041.918311
# LSTM_RMSE    1556.959842
# Pers_MAE     1028.309219
# Pers_RMSE    1819.835479
# MA_MAE       1257.881894
# MA_RMSE      2019.404938
# Name: zBIq5rxdHJRwDNY, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for zVJPv84UY57bAof:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_DC_zVJPv84UY57bAof_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_DC_zVJPv84UY57bAof_error.png
#
# ----- Metrics for zVJPv84UY57bAof (DC) -----
# LSTM_MAE      870.243646
# LSTM_RMSE    1416.716473
# Pers_MAE       987.65253
# Pers_RMSE    1760.444653
# MA_MAE       1211.327174
# MA_RMSE      1948.969278
# Name: zVJPv84UY57bAof, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for YxYtjZvoooNbGkE:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_DC_YxYtjZvoooNbGkE_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_DC_YxYtjZvoooNbGkE_error.png
#
# ----- Metrics for YxYtjZvoooNbGkE (DC) -----
# LSTM_MAE      864.305735
# LSTM_RMSE    1351.808315
# Pers_MAE      965.622904
# Pers_RMSE    1751.640653
# MA_MAE       1211.201815
# MA_RMSE       1946.93669
# Name: YxYtjZvoooNbGkE, dtype: object
#
# ----------------------------------------------

# %% [markdown]
# ### Plant 1 - AC

# %%
visualize_lstm_results(
    df_ps1,
    results_p1_ac_df,
    raw_p1_ac,
    "AC",
    50,
    plant_name="Plant1"
)
# Out:
# ==============================
#  Saving LSTM Plots for Plant1 (AC)
# ==============================
#
# 📁 Saved plots for 1BY6WEcLGh8j5v7:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_AC_1BY6WEcLGh8j5v7_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_AC_1BY6WEcLGh8j5v7_error.png
#
# ----- Metrics for 1BY6WEcLGh8j5v7 (AC) -----
# LSTM_MAE      94.929348
# LSTM_RMSE    131.975305
# Pers_MAE      90.620942
# Pers_RMSE    158.669991
# MA_MAE       110.688427
# MA_RMSE      174.945425
# Name: 1BY6WEcLGh8j5v7, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for 1IF53ai7Xc0U56Y:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_AC_1IF53ai7Xc0U56Y_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_AC_1IF53ai7Xc0U56Y_error.png
#
# ----- Metrics for 1IF53ai7Xc0U56Y (AC) -----
# LSTM_MAE      85.642427
# LSTM_RMSE    134.252352
# Pers_MAE      97.429369
# Pers_RMSE    173.169825
# MA_MAE         119.2275
# MA_RMSE      191.844999
# Name: 1IF53ai7Xc0U56Y, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for 3PZuoBAID5Wc2HD:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_AC_3PZuoBAID5Wc2HD_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_AC_3PZuoBAID5Wc2HD_error.png
#
# ----- Metrics for 3PZuoBAID5Wc2HD (AC) -----
# LSTM_MAE      85.342027
# LSTM_RMSE    129.971228
# Pers_MAE      97.137957
# Pers_RMSE     171.22978
# MA_MAE       115.969441
# MA_RMSE      187.989427
# Name: 3PZuoBAID5Wc2HD, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for 7JYdWkrLSPkdwr4:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_AC_7JYdWkrLSPkdwr4_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_AC_7JYdWkrLSPkdwr4_error.png
#
# ----- Metrics for 7JYdWkrLSPkdwr4 (AC) -----
# LSTM_MAE      88.752917
# LSTM_RMSE    140.557246
# Pers_MAE        95.9418
# Pers_RMSE    168.567515
# MA_MAE       117.216114
# MA_RMSE      185.670745
# Name: 7JYdWkrLSPkdwr4, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for McdE0feGgRqW7Ca:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_AC_McdE0feGgRqW7Ca_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_AC_McdE0feGgRqW7Ca_error.png
#
# ----- Metrics for McdE0feGgRqW7Ca (AC) -----
# LSTM_MAE      76.189366
# LSTM_RMSE    130.691426
# Pers_MAE       98.10668
# Pers_RMSE    175.709121
# MA_MAE       121.063068
# MA_RMSE      194.233328
# Name: McdE0feGgRqW7Ca, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for VHMLBKoKgIrUVDU:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_AC_VHMLBKoKgIrUVDU_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_AC_VHMLBKoKgIrUVDU_error.png
#
# ----- Metrics for VHMLBKoKgIrUVDU (AC) -----
# LSTM_MAE      83.365602
# LSTM_RMSE    134.566277
# Pers_MAE      99.202908
# Pers_RMSE    172.836365
# MA_MAE       120.273593
# MA_RMSE      190.590393
# Name: VHMLBKoKgIrUVDU, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for WRmjgnKYAwPKWDb:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_AC_WRmjgnKYAwPKWDb_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_AC_WRmjgnKYAwPKWDb_error.png
#
# ----- Metrics for WRmjgnKYAwPKWDb (AC) -----
# LSTM_MAE      84.350465
# LSTM_RMSE    132.605883
# Pers_MAE      96.529402
# Pers_RMSE    169.821542
# MA_MAE        114.49309
# MA_RMSE      186.553725
# Name: WRmjgnKYAwPKWDb, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for ZnxXDlPa8U1GXgE:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_AC_ZnxXDlPa8U1GXgE_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_AC_ZnxXDlPa8U1GXgE_error.png
#
# ----- Metrics for ZnxXDlPa8U1GXgE (AC) -----
# LSTM_MAE       87.71094
# LSTM_RMSE    136.258933
# Pers_MAE      97.260739
# Pers_RMSE    172.297983
# MA_MAE       119.017088
# MA_RMSE      190.140424
# Name: ZnxXDlPa8U1GXgE, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for ZoEaEvLYb1n2sOq:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_AC_ZoEaEvLYb1n2sOq_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_AC_ZoEaEvLYb1n2sOq_error.png
#
# ----- Metrics for ZoEaEvLYb1n2sOq (AC) -----
# LSTM_MAE      82.393735
# LSTM_RMSE    132.980636
# Pers_MAE      96.403406
# Pers_RMSE    171.707318
# MA_MAE       118.721197
# MA_RMSE      190.081258
# Name: ZoEaEvLYb1n2sOq, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for adLQvlD726eNBSB:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_AC_adLQvlD726eNBSB_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_AC_adLQvlD726eNBSB_error.png
#
# ----- Metrics for adLQvlD726eNBSB (AC) -----
# LSTM_MAE      83.203142
# LSTM_RMSE    129.919006
# Pers_MAE       99.28863
# Pers_RMSE    175.608486
# MA_MAE       120.259925
# MA_RMSE      193.613587
# Name: adLQvlD726eNBSB, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for bvBOhCH3iADSZry:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_AC_bvBOhCH3iADSZry_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_AC_bvBOhCH3iADSZry_error.png
#
# ----- Metrics for bvBOhCH3iADSZry (AC) -----
# LSTM_MAE      93.471002
# LSTM_RMSE    132.522121
# Pers_MAE      88.879838
# Pers_RMSE    154.701709
# MA_MAE         108.4429
# MA_RMSE      171.529225
# Name: bvBOhCH3iADSZry, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for iCRJl6heRkivqQ3:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_AC_iCRJl6heRkivqQ3_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_AC_iCRJl6heRkivqQ3_error.png
#
# ----- Metrics for iCRJl6heRkivqQ3 (AC) -----
# LSTM_MAE      76.153367
# LSTM_RMSE    129.992475
# Pers_MAE      97.634408
# Pers_RMSE    174.269043
# MA_MAE       119.430167
# MA_RMSE      191.531767
# Name: iCRJl6heRkivqQ3, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for ih0vzX44oOqAx2f:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_AC_ih0vzX44oOqAx2f_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_AC_ih0vzX44oOqAx2f_error.png
#
# ----- Metrics for ih0vzX44oOqAx2f (AC) -----
# LSTM_MAE      83.108242
# LSTM_RMSE    136.723439
# Pers_MAE      94.959126
# Pers_RMSE    168.797286
# MA_MAE       116.153822
# MA_RMSE      185.885189
# Name: ih0vzX44oOqAx2f, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for pkci93gMrogZuBj:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_AC_pkci93gMrogZuBj_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_AC_pkci93gMrogZuBj_error.png
#
# ----- Metrics for pkci93gMrogZuBj (AC) -----
# LSTM_MAE      80.674908
# LSTM_RMSE    128.613332
# Pers_MAE      97.850711
# Pers_RMSE    176.304114
# MA_MAE       119.016588
# MA_RMSE      192.182626
# Name: pkci93gMrogZuBj, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for rGa61gmuvPhdLxV:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_AC_rGa61gmuvPhdLxV_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_AC_rGa61gmuvPhdLxV_error.png
#
# ----- Metrics for rGa61gmuvPhdLxV (AC) -----
# LSTM_MAE      81.837878
# LSTM_RMSE    132.604349
# Pers_MAE      97.809507
# Pers_RMSE     174.07595
# MA_MAE       119.513414
# MA_RMSE      191.861875
# Name: rGa61gmuvPhdLxV, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for sjndEbLyjtCKgGv:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_AC_sjndEbLyjtCKgGv_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_AC_sjndEbLyjtCKgGv_error.png
#
# ----- Metrics for sjndEbLyjtCKgGv (AC) -----
# LSTM_MAE      78.607549
# LSTM_RMSE    128.123581
# Pers_MAE      96.626926
# Pers_RMSE    172.751866
# MA_MAE       118.750252
# MA_RMSE      190.451193
# Name: sjndEbLyjtCKgGv, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for uHbuxQJl8lW7ozc:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_AC_uHbuxQJl8lW7ozc_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_AC_uHbuxQJl8lW7ozc_error.png
#
# ----- Metrics for uHbuxQJl8lW7ozc (AC) -----
# LSTM_MAE     105.727704
# LSTM_RMSE     147.76098
# Pers_MAE      97.894246
# Pers_RMSE    176.237114
# MA_MAE       119.948024
# MA_RMSE      193.141047
# Name: uHbuxQJl8lW7ozc, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for wCURE6d3bPkepu2:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_AC_wCURE6d3bPkepu2_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_AC_wCURE6d3bPkepu2_error.png
#
# ----- Metrics for wCURE6d3bPkepu2 (AC) -----
# LSTM_MAE      83.425411
# LSTM_RMSE    135.669917
# Pers_MAE      97.793676
# Pers_RMSE    173.582874
# MA_MAE        119.47518
# MA_RMSE      191.001866
# Name: wCURE6d3bPkepu2, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for z9Y9gH1T5YWrNuG:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_AC_z9Y9gH1T5YWrNuG_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_AC_z9Y9gH1T5YWrNuG_error.png
#
# ----- Metrics for z9Y9gH1T5YWrNuG (AC) -----
# LSTM_MAE      83.109325
# LSTM_RMSE    132.248554
# Pers_MAE      95.622421
# Pers_RMSE    169.434228
# MA_MAE       117.302369
# MA_RMSE      187.522546
# Name: z9Y9gH1T5YWrNuG, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for zBIq5rxdHJRwDNY:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_AC_zBIq5rxdHJRwDNY_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_AC_zBIq5rxdHJRwDNY_error.png
#
# ----- Metrics for zBIq5rxdHJRwDNY (AC) -----
# LSTM_MAE      98.865052
# LSTM_RMSE    154.034022
# Pers_MAE      100.45745
# Pers_RMSE    177.652677
# MA_MAE       122.895893
# MA_RMSE      197.223329
# Name: zBIq5rxdHJRwDNY, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for zVJPv84UY57bAof:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_AC_zVJPv84UY57bAof_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_AC_zVJPv84UY57bAof_error.png
#
# ----- Metrics for zVJPv84UY57bAof (AC) -----
# LSTM_MAE      82.109122
# LSTM_RMSE    134.848537
# Pers_MAE      96.475066
# Pers_RMSE    171.848378
# MA_MAE       118.334912
# MA_RMSE      190.356021
# Name: zVJPv84UY57bAof, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for YxYtjZvoooNbGkE:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_AC_YxYtjZvoooNbGkE_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant1_AC_YxYtjZvoooNbGkE_error.png
#
# ----- Metrics for YxYtjZvoooNbGkE (AC) -----
# LSTM_MAE      90.192884
# LSTM_RMSE    136.770628
# Pers_MAE      94.283392
# Pers_RMSE    170.913235
# MA_MAE       118.276021
# MA_RMSE      190.090544
# Name: YxYtjZvoooNbGkE, dtype: object
#
# ----------------------------------------------

# %% [markdown]
# ### Plant 2 – DC

# %%
visualize_lstm_results(
    df_ps2,
    results_p2_ac_df,
    raw_p2_ac,
    "AC",
    50,
    plant_name="Plant2"
)
# Out:
# ==============================
#  Saving LSTM Plots for Plant2 (AC)
# ==============================
#
# 📁 Saved plots for 4UPUqMRk7TRMgml:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_4UPUqMRk7TRMgml_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_4UPUqMRk7TRMgml_error.png
#
# ----- Metrics for 4UPUqMRk7TRMgml (AC) -----
# LSTM_MAE      94.643091
# LSTM_RMSE    155.688072
# Pers_MAE      92.521622
# Pers_RMSE    162.886294
# MA_MAE        98.686355
# MA_RMSE       159.91432
# Name: 4UPUqMRk7TRMgml, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for 81aHJ1q11NBPMrL:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_81aHJ1q11NBPMrL_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_81aHJ1q11NBPMrL_error.png
#
# ----- Metrics for 81aHJ1q11NBPMrL (AC) -----
# LSTM_MAE      91.751213
# LSTM_RMSE    140.674768
# Pers_MAE     102.321885
# Pers_RMSE    175.151336
# MA_MAE       110.717829
# MA_RMSE      180.813577
# Name: 81aHJ1q11NBPMrL, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for 9kRcWv60rDACzjR:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_9kRcWv60rDACzjR_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_9kRcWv60rDACzjR_error.png
#
# ----- Metrics for 9kRcWv60rDACzjR (AC) -----
# LSTM_MAE      90.622565
# LSTM_RMSE    142.952484
# Pers_MAE      99.153648
# Pers_RMSE    171.737498
# MA_MAE        107.93968
# MA_RMSE      175.638596
# Name: 9kRcWv60rDACzjR, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for Et9kgGMDl729KT4:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_Et9kgGMDl729KT4_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_Et9kgGMDl729KT4_error.png
#
# ----- Metrics for Et9kgGMDl729KT4 (AC) -----
# LSTM_MAE      86.897708
# LSTM_RMSE    125.144607
# Pers_MAE      79.685379
# Pers_RMSE    139.275408
# MA_MAE        88.257116
# MA_RMSE      142.982355
# Name: Et9kgGMDl729KT4, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for IQ2d7wF4YD8zU1Q:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_IQ2d7wF4YD8zU1Q_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_IQ2d7wF4YD8zU1Q_error.png
#
# ----- Metrics for IQ2d7wF4YD8zU1Q (AC) -----
# LSTM_MAE     111.817817
# LSTM_RMSE    151.149106
# Pers_MAE     112.729539
# Pers_RMSE    185.984408
# MA_MAE       115.838003
# MA_RMSE      179.696196
# Name: IQ2d7wF4YD8zU1Q, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for LYwnQax7tkwH5Cb:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_LYwnQax7tkwH5Cb_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_LYwnQax7tkwH5Cb_error.png
#
# ----- Metrics for LYwnQax7tkwH5Cb (AC) -----
# LSTM_MAE      94.521176
# LSTM_RMSE    147.747469
# Pers_MAE      97.385961
# Pers_RMSE    164.706334
# MA_MAE       102.999524
# MA_RMSE      169.578633
# Name: LYwnQax7tkwH5Cb, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for LlT2YUhhzqhg5Sw:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_LlT2YUhhzqhg5Sw_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_LlT2YUhhzqhg5Sw_error.png
#
# ----- Metrics for LlT2YUhhzqhg5Sw (AC) -----
# LSTM_MAE      89.530922
# LSTM_RMSE    142.959005
# Pers_MAE      99.526374
# Pers_RMSE    171.126711
# MA_MAE       106.717133
# MA_RMSE      174.645307
# Name: LlT2YUhhzqhg5Sw, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for Mx2yZCDsyf6DPfv:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_Mx2yZCDsyf6DPfv_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_Mx2yZCDsyf6DPfv_error.png
#
# ----- Metrics for Mx2yZCDsyf6DPfv (AC) -----
# LSTM_MAE     103.903015
# LSTM_RMSE    150.716444
# Pers_MAE      91.758785
# Pers_RMSE    161.892123
# MA_MAE       103.183557
# MA_RMSE      167.488102
# Name: Mx2yZCDsyf6DPfv, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for NgDl19wMapZy17u:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_NgDl19wMapZy17u_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_NgDl19wMapZy17u_error.png
#
# ----- Metrics for NgDl19wMapZy17u (AC) -----
# LSTM_MAE      94.539142
# LSTM_RMSE    139.170645
# Pers_MAE     113.509516
# Pers_RMSE    187.876854
# MA_MAE       116.048788
# MA_RMSE      180.241518
# Name: NgDl19wMapZy17u, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for PeE6FRyGXUgsRhN:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_PeE6FRyGXUgsRhN_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_PeE6FRyGXUgsRhN_error.png
#
# ----- Metrics for PeE6FRyGXUgsRhN (AC) -----
# LSTM_MAE      90.818691
# LSTM_RMSE    147.068826
# Pers_MAE      95.345732
# Pers_RMSE    165.497412
# MA_MAE       107.093559
# MA_RMSE      175.646368
# Name: PeE6FRyGXUgsRhN, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for Qf4GUc1pJu5T6c6:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_Qf4GUc1pJu5T6c6_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_Qf4GUc1pJu5T6c6_error.png
#
# ----- Metrics for Qf4GUc1pJu5T6c6 (AC) -----
# LSTM_MAE       80.52062
# LSTM_RMSE    147.688201
# Pers_MAE      91.740304
# Pers_RMSE     155.99125
# MA_MAE        99.530016
# MA_RMSE      157.159659
# Name: Qf4GUc1pJu5T6c6, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for Quc1TzYxW2pYoWX:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_Quc1TzYxW2pYoWX_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_Quc1TzYxW2pYoWX_error.png
#
# ----- Metrics for Quc1TzYxW2pYoWX (AC) -----
# LSTM_MAE      81.472409
# LSTM_RMSE    121.671517
# Pers_MAE       80.33994
# Pers_RMSE     132.95648
# MA_MAE         88.50369
# MA_RMSE      138.756083
# Name: Quc1TzYxW2pYoWX, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for V94E5Ben1TlhnDV:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_V94E5Ben1TlhnDV_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_V94E5Ben1TlhnDV_error.png
#
# ----- Metrics for V94E5Ben1TlhnDV (AC) -----
# LSTM_MAE      86.794067
# LSTM_RMSE    148.719276
# Pers_MAE      91.105746
# Pers_RMSE    165.525746
# MA_MAE       104.086081
# MA_RMSE      171.817463
# Name: V94E5Ben1TlhnDV, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for WcxssY2VbP4hApt:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_WcxssY2VbP4hApt_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_WcxssY2VbP4hApt_error.png
#
# ----- Metrics for WcxssY2VbP4hApt (AC) -----
# LSTM_MAE      91.599866
# LSTM_RMSE    143.431584
# Pers_MAE     102.905765
# Pers_RMSE    177.516134
# MA_MAE       111.807971
# MA_RMSE      182.081464
# Name: WcxssY2VbP4hApt, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for mqwcsP2rE7J0TFp:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_mqwcsP2rE7J0TFp_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_mqwcsP2rE7J0TFp_error.png
#
# ----- Metrics for mqwcsP2rE7J0TFp (AC) -----
# LSTM_MAE     110.276053
# LSTM_RMSE    147.637923
# Pers_MAE     113.057141
# Pers_RMSE    188.098994
# MA_MAE       116.099133
# MA_RMSE      179.557566
# Name: mqwcsP2rE7J0TFp, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for oZ35aAeoifZaQzV:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_oZ35aAeoifZaQzV_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_oZ35aAeoifZaQzV_error.png
#
# ----- Metrics for oZ35aAeoifZaQzV (AC) -----
# LSTM_MAE      96.980297
# LSTM_RMSE    158.095622
# Pers_MAE       95.57326
# Pers_RMSE    168.266944
# MA_MAE       109.037451
# MA_RMSE      176.067704
# Name: oZ35aAeoifZaQzV, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for oZZkBaNadn6DNKz:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_oZZkBaNadn6DNKz_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_oZZkBaNadn6DNKz_error.png
#
# ----- Metrics for oZZkBaNadn6DNKz (AC) -----
# LSTM_MAE       85.55854
# LSTM_RMSE     144.08124
# Pers_MAE      91.215839
# Pers_RMSE    164.070985
# MA_MAE       103.765651
# MA_RMSE      170.333076
# Name: oZZkBaNadn6DNKz, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for q49J1IKaHRwDQnt:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_q49J1IKaHRwDQnt_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_q49J1IKaHRwDQnt_error.png
#
# ----- Metrics for q49J1IKaHRwDQnt (AC) -----
# LSTM_MAE      89.637715
# LSTM_RMSE    147.853202
# Pers_MAE     105.870749
# Pers_RMSE    181.107498
# MA_MAE       110.101969
# MA_RMSE      181.633723
# Name: q49J1IKaHRwDQnt, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for rrq4fwE8jgrTyWY:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_rrq4fwE8jgrTyWY_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_rrq4fwE8jgrTyWY_error.png
#
# ----- Metrics for rrq4fwE8jgrTyWY (AC) -----
# LSTM_MAE      82.417698
# LSTM_RMSE      139.3189
# Pers_MAE      92.498594
# Pers_RMSE    158.068523
# MA_MAE       102.990276
# MA_RMSE      168.718428
# Name: rrq4fwE8jgrTyWY, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for vOuJvMaM2sgwLmb:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_vOuJvMaM2sgwLmb_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_vOuJvMaM2sgwLmb_error.png
#
# ----- Metrics for vOuJvMaM2sgwLmb (AC) -----
# LSTM_MAE      90.253059
# LSTM_RMSE    139.273846
# Pers_MAE     100.394387
# Pers_RMSE    172.684188
# MA_MAE       110.169036
# MA_RMSE      178.862257
# Name: vOuJvMaM2sgwLmb, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for xMbIugepa2P7lBB:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_xMbIugepa2P7lBB_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_xMbIugepa2P7lBB_error.png
#
# ----- Metrics for xMbIugepa2P7lBB (AC) -----
# LSTM_MAE     131.266463
# LSTM_RMSE    175.798286
# Pers_MAE     110.265755
# Pers_RMSE    183.115354
# MA_MAE       114.198991
# MA_RMSE      176.828935
# Name: xMbIugepa2P7lBB, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for xoJJ8DcxJEcupym:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_xoJJ8DcxJEcupym_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_xoJJ8DcxJEcupym_error.png
#
# ----- Metrics for xoJJ8DcxJEcupym (AC) -----
# LSTM_MAE      94.053269
# LSTM_RMSE    149.974517
# Pers_MAE     102.052918
# Pers_RMSE    176.638485
# MA_MAE       110.966177
# MA_RMSE      181.788438
# Name: xoJJ8DcxJEcupym, dtype: object
#
# ----------------------------------------------

# %% [markdown]
# ### Plant 2 – AC

# %%
visualize_lstm_results(
    df_ps2,
    results_p2_ac_df,
    raw_p2_ac,
    "AC",
    50,
    plant_name="Plant2"
)
# Out:
# ==============================
#  Saving LSTM Plots for Plant2 (AC)
# ==============================
#
# 📁 Saved plots for 4UPUqMRk7TRMgml:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_4UPUqMRk7TRMgml_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_4UPUqMRk7TRMgml_error.png
#
# ----- Metrics for 4UPUqMRk7TRMgml (AC) -----
# LSTM_MAE      94.643091
# LSTM_RMSE    155.688072
# Pers_MAE      92.521622
# Pers_RMSE    162.886294
# MA_MAE        98.686355
# MA_RMSE       159.91432
# Name: 4UPUqMRk7TRMgml, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for 81aHJ1q11NBPMrL:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_81aHJ1q11NBPMrL_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_81aHJ1q11NBPMrL_error.png
#
# ----- Metrics for 81aHJ1q11NBPMrL (AC) -----
# LSTM_MAE      91.751213
# LSTM_RMSE    140.674768
# Pers_MAE     102.321885
# Pers_RMSE    175.151336
# MA_MAE       110.717829
# MA_RMSE      180.813577
# Name: 81aHJ1q11NBPMrL, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for 9kRcWv60rDACzjR:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_9kRcWv60rDACzjR_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_9kRcWv60rDACzjR_error.png
#
# ----- Metrics for 9kRcWv60rDACzjR (AC) -----
# LSTM_MAE      90.622565
# LSTM_RMSE    142.952484
# Pers_MAE      99.153648
# Pers_RMSE    171.737498
# MA_MAE        107.93968
# MA_RMSE      175.638596
# Name: 9kRcWv60rDACzjR, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for Et9kgGMDl729KT4:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_Et9kgGMDl729KT4_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_Et9kgGMDl729KT4_error.png
#
# ----- Metrics for Et9kgGMDl729KT4 (AC) -----
# LSTM_MAE      86.897708
# LSTM_RMSE    125.144607
# Pers_MAE      79.685379
# Pers_RMSE    139.275408
# MA_MAE        88.257116
# MA_RMSE      142.982355
# Name: Et9kgGMDl729KT4, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for IQ2d7wF4YD8zU1Q:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_IQ2d7wF4YD8zU1Q_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_IQ2d7wF4YD8zU1Q_error.png
#
# ----- Metrics for IQ2d7wF4YD8zU1Q (AC) -----
# LSTM_MAE     111.817817
# LSTM_RMSE    151.149106
# Pers_MAE     112.729539
# Pers_RMSE    185.984408
# MA_MAE       115.838003
# MA_RMSE      179.696196
# Name: IQ2d7wF4YD8zU1Q, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for LYwnQax7tkwH5Cb:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_LYwnQax7tkwH5Cb_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_LYwnQax7tkwH5Cb_error.png
#
# ----- Metrics for LYwnQax7tkwH5Cb (AC) -----
# LSTM_MAE      94.521176
# LSTM_RMSE    147.747469
# Pers_MAE      97.385961
# Pers_RMSE    164.706334
# MA_MAE       102.999524
# MA_RMSE      169.578633
# Name: LYwnQax7tkwH5Cb, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for LlT2YUhhzqhg5Sw:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_LlT2YUhhzqhg5Sw_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_LlT2YUhhzqhg5Sw_error.png
#
# ----- Metrics for LlT2YUhhzqhg5Sw (AC) -----
# LSTM_MAE      89.530922
# LSTM_RMSE    142.959005
# Pers_MAE      99.526374
# Pers_RMSE    171.126711
# MA_MAE       106.717133
# MA_RMSE      174.645307
# Name: LlT2YUhhzqhg5Sw, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for Mx2yZCDsyf6DPfv:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_Mx2yZCDsyf6DPfv_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_Mx2yZCDsyf6DPfv_error.png
#
# ----- Metrics for Mx2yZCDsyf6DPfv (AC) -----
# LSTM_MAE     103.903015
# LSTM_RMSE    150.716444
# Pers_MAE      91.758785
# Pers_RMSE    161.892123
# MA_MAE       103.183557
# MA_RMSE      167.488102
# Name: Mx2yZCDsyf6DPfv, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for NgDl19wMapZy17u:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_NgDl19wMapZy17u_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_NgDl19wMapZy17u_error.png
#
# ----- Metrics for NgDl19wMapZy17u (AC) -----
# LSTM_MAE      94.539142
# LSTM_RMSE    139.170645
# Pers_MAE     113.509516
# Pers_RMSE    187.876854
# MA_MAE       116.048788
# MA_RMSE      180.241518
# Name: NgDl19wMapZy17u, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for PeE6FRyGXUgsRhN:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_PeE6FRyGXUgsRhN_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_PeE6FRyGXUgsRhN_error.png
#
# ----- Metrics for PeE6FRyGXUgsRhN (AC) -----
# LSTM_MAE      90.818691
# LSTM_RMSE    147.068826
# Pers_MAE      95.345732
# Pers_RMSE    165.497412
# MA_MAE       107.093559
# MA_RMSE      175.646368
# Name: PeE6FRyGXUgsRhN, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for Qf4GUc1pJu5T6c6:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_Qf4GUc1pJu5T6c6_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_Qf4GUc1pJu5T6c6_error.png
#
# ----- Metrics for Qf4GUc1pJu5T6c6 (AC) -----
# LSTM_MAE       80.52062
# LSTM_RMSE    147.688201
# Pers_MAE      91.740304
# Pers_RMSE     155.99125
# MA_MAE        99.530016
# MA_RMSE      157.159659
# Name: Qf4GUc1pJu5T6c6, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for Quc1TzYxW2pYoWX:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_Quc1TzYxW2pYoWX_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_Quc1TzYxW2pYoWX_error.png
#
# ----- Metrics for Quc1TzYxW2pYoWX (AC) -----
# LSTM_MAE      81.472409
# LSTM_RMSE    121.671517
# Pers_MAE       80.33994
# Pers_RMSE     132.95648
# MA_MAE         88.50369
# MA_RMSE      138.756083
# Name: Quc1TzYxW2pYoWX, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for V94E5Ben1TlhnDV:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_V94E5Ben1TlhnDV_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_V94E5Ben1TlhnDV_error.png
#
# ----- Metrics for V94E5Ben1TlhnDV (AC) -----
# LSTM_MAE      86.794067
# LSTM_RMSE    148.719276
# Pers_MAE      91.105746
# Pers_RMSE    165.525746
# MA_MAE       104.086081
# MA_RMSE      171.817463
# Name: V94E5Ben1TlhnDV, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for WcxssY2VbP4hApt:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_WcxssY2VbP4hApt_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_WcxssY2VbP4hApt_error.png
#
# ----- Metrics for WcxssY2VbP4hApt (AC) -----
# LSTM_MAE      91.599866
# LSTM_RMSE    143.431584
# Pers_MAE     102.905765
# Pers_RMSE    177.516134
# MA_MAE       111.807971
# MA_RMSE      182.081464
# Name: WcxssY2VbP4hApt, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for mqwcsP2rE7J0TFp:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_mqwcsP2rE7J0TFp_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_mqwcsP2rE7J0TFp_error.png
#
# ----- Metrics for mqwcsP2rE7J0TFp (AC) -----
# LSTM_MAE     110.276053
# LSTM_RMSE    147.637923
# Pers_MAE     113.057141
# Pers_RMSE    188.098994
# MA_MAE       116.099133
# MA_RMSE      179.557566
# Name: mqwcsP2rE7J0TFp, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for oZ35aAeoifZaQzV:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_oZ35aAeoifZaQzV_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_oZ35aAeoifZaQzV_error.png
#
# ----- Metrics for oZ35aAeoifZaQzV (AC) -----
# LSTM_MAE      96.980297
# LSTM_RMSE    158.095622
# Pers_MAE       95.57326
# Pers_RMSE    168.266944
# MA_MAE       109.037451
# MA_RMSE      176.067704
# Name: oZ35aAeoifZaQzV, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for oZZkBaNadn6DNKz:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_oZZkBaNadn6DNKz_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_oZZkBaNadn6DNKz_error.png
#
# ----- Metrics for oZZkBaNadn6DNKz (AC) -----
# LSTM_MAE       85.55854
# LSTM_RMSE     144.08124
# Pers_MAE      91.215839
# Pers_RMSE    164.070985
# MA_MAE       103.765651
# MA_RMSE      170.333076
# Name: oZZkBaNadn6DNKz, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for q49J1IKaHRwDQnt:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_q49J1IKaHRwDQnt_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_q49J1IKaHRwDQnt_error.png
#
# ----- Metrics for q49J1IKaHRwDQnt (AC) -----
# LSTM_MAE      89.637715
# LSTM_RMSE    147.853202
# Pers_MAE     105.870749
# Pers_RMSE    181.107498
# MA_MAE       110.101969
# MA_RMSE      181.633723
# Name: q49J1IKaHRwDQnt, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for rrq4fwE8jgrTyWY:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_rrq4fwE8jgrTyWY_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_rrq4fwE8jgrTyWY_error.png
#
# ----- Metrics for rrq4fwE8jgrTyWY (AC) -----
# LSTM_MAE      82.417698
# LSTM_RMSE      139.3189
# Pers_MAE      92.498594
# Pers_RMSE    158.068523
# MA_MAE       102.990276
# MA_RMSE      168.718428
# Name: rrq4fwE8jgrTyWY, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for vOuJvMaM2sgwLmb:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_vOuJvMaM2sgwLmb_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_vOuJvMaM2sgwLmb_error.png
#
# ----- Metrics for vOuJvMaM2sgwLmb (AC) -----
# LSTM_MAE      90.253059
# LSTM_RMSE    139.273846
# Pers_MAE     100.394387
# Pers_RMSE    172.684188
# MA_MAE       110.169036
# MA_RMSE      178.862257
# Name: vOuJvMaM2sgwLmb, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for xMbIugepa2P7lBB:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_xMbIugepa2P7lBB_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_xMbIugepa2P7lBB_error.png
#
# ----- Metrics for xMbIugepa2P7lBB (AC) -----
# LSTM_MAE     131.266463
# LSTM_RMSE    175.798286
# Pers_MAE     110.265755
# Pers_RMSE    183.115354
# MA_MAE       114.198991
# MA_RMSE      176.828935
# Name: xMbIugepa2P7lBB, dtype: object
#
# ----------------------------------------------
#
# 📁 Saved plots for xoJJ8DcxJEcupym:
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_xoJJ8DcxJEcupym_forecast.png
#    → C:\Users\B.KING\OneDrive - Imperial College London\CIVE70111 Machine Learning\CouseWork\Group-11\data\06 LSTM Forecasting Model\Plots\Plant2_AC_xoJJ8DcxJEcupym_error.png
#
# ----- Metrics for xoJJ8DcxJEcupym (AC) -----
# LSTM_MAE      94.053269
# LSTM_RMSE    149.974517
# Pers_MAE     102.052918
# Pers_RMSE    176.638485
# MA_MAE       110.966177
# MA_RMSE      181.788438
# Name: xoJJ8DcxJEcupym, dtype: object
#
# ----------------------------------------------
